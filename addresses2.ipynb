# %%
from validate_adrresses import validate_address, remove_duplicates_preserve_order
import pandas as pd
import os
from tqdm import tqdm
print(os.getcwd())
# Out:
# c:\Users\lagg1\Documents\Belcorp\iteration_adresses

# %%
df = pd.read_csv('./data/direcciones.csv', sep=';')
# Out:
# C:\Users\lagg1\AppData\Local\Temp\ipykernel_23764\4095483860.py:1: DtypeWarning: Columns (4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/direcciones.csv', sep=';')

# %%
cols = [col for col in df]
col1 = cols[:3]
col2 = cols[3:]

cols = []
for col in col1:
    cols.append(col)
cols.append("NUEVA DIRECCION")
for col in col2:
    cols.append(col)

# %%
df["NUEVA DIRECCION"] = None
df = df.reindex(columns=cols)
df = df[df["IND TERRITORIOS"] == 9]

# %%
df_tmp = df[["DIRECCION DE DOMICILIO", "COMUNA DOMICILIO", "NUEVA DIRECCION", "X", "Y"]]
df_tmp = df_tmp[1000:2000]
df_tmp
# Out:
#                                   DIRECCION DE DOMICILIO COMUNA DOMICILIO  \
# 5053                          PJE .COLCUMA TIRUA 0 TIRUA            TIRUA
# 5057                              BERNARDO OHIGGINS CASA            MAFIL
# 5059                  LAS PARCELAS AVENIDA PADRE HURTADO        EL BOSQUE
# 5061                           ANIBAL PINTO ESQUINA SOTO          MULCHEN
# 5066   AV. EL TEPUAL PARQUE HOSSAMONTT BODEGA 19 ATRA...     PUERTO MONTT
# ...                                                  ...              ...
# 10021  AVDA VILLA DEL SOL 73.PUERTO VARAS.LOS LAGOS. ...     PUERTO VARAS
# 10028                      CALLE SN 0 Carampangue ARAUCO           ARAUCO
# 10029         LO DE LOBOS SN.RENGO.OHIGGINS. LO DE LOBOS            RENGO
# 10034                         M MONTT X A  PRAT LA UNION         LA UNION
# 10045                          RIO CHAPA 10460 LA GRANJA        LA GRANJA
#
#       NUEVA DIRECCION                     X                     Y
# 5053             None
# 5057             None
# 5059             None
# 5061             None
# 5066             None
# ...               ...                   ...                   ...
# 10021            None
# 10028            None
# 10029            None
# 10034            None
# 10045            None
#
# [1000 rows x 5 columns]

# %%
df_tmp["DIRECCION TOTAL"] =  df_tmp.apply(lambda row: remove_duplicates_preserve_order(row["DIRECCION DE DOMICILIO"] + " " + row["COMUNA DOMICILIO"]),axis=1)

# %%
df_tmp
# Out:
#                                   DIRECCION DE DOMICILIO COMUNA DOMICILIO  \
# 5053                          PJE .COLCUMA TIRUA 0 TIRUA            TIRUA
# 5057                              BERNARDO OHIGGINS CASA            MAFIL
# 5059                  LAS PARCELAS AVENIDA PADRE HURTADO        EL BOSQUE
# 5061                           ANIBAL PINTO ESQUINA SOTO          MULCHEN
# 5066   AV. EL TEPUAL PARQUE HOSSAMONTT BODEGA 19 ATRA...     PUERTO MONTT
# ...                                                  ...              ...
# 10021  AVDA VILLA DEL SOL 73.PUERTO VARAS.LOS LAGOS. ...     PUERTO VARAS
# 10028                      CALLE SN 0 Carampangue ARAUCO           ARAUCO
# 10029         LO DE LOBOS SN.RENGO.OHIGGINS. LO DE LOBOS            RENGO
# 10034                         M MONTT X A  PRAT LA UNION         LA UNION
# 10045                          RIO CHAPA 10460 LA GRANJA        LA GRANJA
#
#       NUEVA DIRECCION                     X                     Y  \
# 5053             None
# 5057             None
# 5059             None
# 5061             None
# 5066             None
# ...               ...                   ...                   ...
# 10021            None
# 10028            None
# 10029            None
# 10034            None
# 10045            None
#
#                                          DIRECCION TOTAL
# 5053                                 PJE_COLCUMA TIRUA 0
# 5057                        BERNARDO OHIGGINS CASA MAFIL
# 5059        LAS_PARCELAS AVENIDA PADRE HURTADO EL_BOSQUE
# 5061                   ANIBAL PINTO ESQUINA SOTO MULCHEN
# 5066   EL_TEPUAL PARQUE HOSSAMONTT BODEGA 19 ATRAS_DE...
# ...                                                  ...
# 10021  AVDA VILLA_DEL_SOL 73 PUERTO VARAS LOS_LAGOS C...
# 10028                         CALLE 0 Carampangue ARAUCO
# 10029                            LO LOBOS RENGO OHIGGINS
# 10034                          M MONTT X A PRAT LA_UNION
# 10045                          RIO CHAPA 10460 LA_GRANJA
#
# [1000 rows x 6 columns]

# %%
arr_df = []
itr = 5
step = len(df_tmp)//itr
for i in range(itr):
    if i < itr - 1:
        arr_df.append(df_tmp[step*i:step*(i+1)])
    else:
        arr_df.append(df_tmp[step*i:])
arr_df[-1]
# Out:
#                                   DIRECCION DE DOMICILIO COMUNA DOMICILIO  \
# 8993       PASAJE UNO SN.RANCAGUA.OHIGGINS. VILLA DORADA         RANCAGUA
# 8994            SANTA VALENTINA SN.CHIMBARONGO.OHIGGINS.      CHIMBARONGO
# 8996               ROBERTO MATTA 112, LANCO, CHILE LANCO            LANCO
# 8998                   ACCESO A ANGELMO CON PASAJE MARTI     PUERTO MONTT
# 9000           AMATISTA  # 932 FRENTE BOMBEROS TALAGANTE        TALAGANTE
# ...                                                  ...              ...
# 10021  AVDA VILLA DEL SOL 73.PUERTO VARAS.LOS LAGOS. ...     PUERTO VARAS
# 10028                      CALLE SN 0 Carampangue ARAUCO           ARAUCO
# 10029         LO DE LOBOS SN.RENGO.OHIGGINS. LO DE LOBOS            RENGO
# 10034                         M MONTT X A  PRAT LA UNION         LA UNION
# 10045                          RIO CHAPA 10460 LA GRANJA        LA GRANJA
#
#       NUEVA DIRECCION                     X                     Y  \
# 8993             None
# 8994             None
# 8996             None
# 8998             None
# 9000             None
# ...               ...                   ...                   ...
# 10021            None
# 10028            None
# 10029            None
# 10034            None
# 10045            None
#
#                                          DIRECCION TOTAL
# 8993           PASAJE_UNO RANCAGUA OHIGGINS VILLA DORADA
# 8994                SANTA VALENTINA CHIMBARONGO OHIGGINS
# 8996                       ROBERTO MATTA 112 LANCO CHILE
# 8998      ACCESO A ANGELMO CON PASAJE_MARTI PUERTO MONTT
# 9000                                      AMATISTA # 932
# ...                                                  ...
# 10021  AVDA VILLA_DEL_SOL 73 PUERTO VARAS LOS_LAGOS C...
# 10028                         CALLE 0 Carampangue ARAUCO
# 10029                            LO LOBOS RENGO OHIGGINS
# 10034                          M MONTT X A PRAT LA_UNION
# 10045                          RIO CHAPA 10460 LA_GRANJA
#
# [200 rows x 6 columns]

# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
from multiprocessing import Pool

def parallel(df_):
    ddata = dd.from_pandas(df_, npartitions=30)

    # Sample meta dataframe to indicate the structure of the output
    meta = pd.DataFrame({
        "DIRECCION DE DOMICILIO": pd.Series(dtype='str'),
        "COMUNA DOMICILIO": pd.Series(dtype='str'),
        "NUEVA DIRECCION": pd.Series(dtype='str'),
        "X": pd.Series(dtype='float'),
        "Y": pd.Series(dtype='float'),
        "DIRECCION TOTAL": pd.Series(dtype='str')
    })

    def apply_validate_address(df_chunk):
        # Handle missing values before passing to validate_address
        df_chunk[["DIRECCION TOTAL"]] = df_chunk[["DIRECCION TOTAL"]].fillna("")
        
        # Apply the validation function to each row and unpack the results
        df_chunk[["NUEVA DIRECCION", "X", "Y"]] = df_chunk.apply(
            lambda row: pd.Series(validate_address(row["DIRECCION TOTAL"])),
            axis=1
        )
        return df_chunk

    # Map the function to each partition, with the meta keyword to define the structure
    res = ddata.map_partitions(apply_validate_address, meta=meta).compute()
    return res

def parallel_wrapper(df):
    return parallel(df)

if __name__ == '__main__':
    arr_df_tmp = []
    arr_df_tmp.append(parallel_wrapper(df_tmp))
# Out:
# sin coincidencias ['T-99-U']  ------  T-99-U
# ['ROBERTO', 'MATTA', '112', 'LANCO', 'CHILE']  ------  ROBERTO MATTA 112 LANCO CHILE  -------  Roberto Matta, VIlla Padre Hurtado, Lanco, Provincia de Valdivia, Región de Los Ríos, Chile
# ['LAS HERAS', '1010', 'PARTE', 'ALTA', 'LA SERENA']  ------  LAS_HERAS 1010 PARTE ALTA LA_SERENA  -------  Juan Gregorio Las Heras, Parte Alta, Coquimbo, Provincia de Elqui, Región de Coquimbo, 1790437, Chile
# ['SANTA', 'ANA', '11', 'SAGRADA', 'FAMILIA']  ------  SANTA ANA 11 SAGRADA FAMILIA  -------  Santa Ana, Sagrada Familia, Provincia de Curicó, Región del Maule, Chile
# ['SAN LEON', 'S-', '33', 'L', '-', 'I', 'POSTE', '510420', 'BERNARDO', 'CHILE', 'LAS ESCANDILLA', 'NOS']  ------  SAN_LEON S- 33 L - I POSTE 510420 BERNARDO CHILE LAS_ESCANDILLA NOS  -------  San León, Villa San Lucas, Quilicura, Provincia de Santiago, Región Metropolitana de Santiago, 8700000, Chile
# ['DEL', 'TOPOGRAFO', 'CASA 2948', 'PUENTE', 'ALTO']  ------  DEL TOPOGRAFO CASA_2948 PUENTE ALTO  -------  Universidad de Chile, Villa Las Acacias, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8150000, Chile
# ['CALLE', 'NUEVA', '1', '13', 'ARICA']  ------  CALLE NUEVA 1 13 ARICA  -------  Calle 1, Poconchile, Santa Rosa, Arica, Provincia de Arica, Región de Arica y Parinacota, Chile
# ['LAS ARAUCARIAS', 'CONSTITUCION', 'MAULE', 'DEPTO', '407']  ------  LAS_ARAUCARIAS CONSTITUCION MAULE DEPTO 407  -------  Las Araucarias, Parral, Provincia de Linares, Región del Maule, 3630000, Chile
# sin coincidencias ['OLIVICANTE', '13140', 'LA PINTANA']  ------  OLIVICANTE 13140 LA_PINTANA
# sin coincidencias ['LAS LIGUSTRINA', '9835', 'SAN RAMON', 'LA CISTERNA']  ------  LAS_LIGUSTRINA 9835 SAN_RAMON LA_CISTERNA
# sin coincidencias ['PA', 'UXMAL', 'NRO', '490']  ------  PA UXMAL NRO 490
# sin coincidencias ['LLANOS', 'CALEHUEL', 'PAIPOTE', 'COPIAPO']  ------  LLANOS CALEHUEL PAIPOTE COPIAPO
# sin coincidencias ['SANTA', 'MONICA', 'SAN CLEMENTE', 'MAULE']  ------  SANTA MONICA SAN_CLEMENTE MAULE
# sin coincidencias ['EL ROBLE', '7623', 'CASA 4', 'ANTOFAGASTA']  ------  EL_ROBLE 7623 CASA_4 ANTOFAGASTA
# sin coincidencias ['TRES', 'PUENTES', 'COINCO', 'OHIGGINS']  ------  TRES PUENTES COINCO OHIGGINS
# ['PORTUGAL', '1386', 'CON', 'CALLE', 'VICTORIA', 'SANTIAGO']  ------  PORTUGAL 1386 CON CALLE VICTORIA SANTIAGO  -------  Pasaje Portugal, Población Manuel Rodríguez, Buin, Provincia de Maipo, Región Metropolitana de Santiago, Chile
# ['SAO', 'PAULO', '542', 'SAN MIGUEL', 'METROPOLITANA', 'PEDRO', 'AGUIRRE', 'CERDA']  ------  SAO PAULO 542 SAN_MIGUEL METROPOLITANA PEDRO AGUIRRE CERDA  -------  Paulo VI, Villa El Cardenal, El Bosque, Provincia de Santiago, Región Metropolitana de Santiago, 8010000, Chile
# sin coincidencias ['CAM', 'A', 'LAS DICHAS']  ------  CAM A LAS_DICHAS
# sin coincidencias ['POLONIA', 'CASA 31-79', 'ALTO', 'HOSPICIO']  ------  POLONIA CASA_31-79 ALTO HOSPICIO
# sin coincidencias ['PJE', 'SAN JUAN', 'CALLE', 'EDUARDO', '1836']  ------  PJE SAN_JUAN CALLE EDUARDO 1836
# sin coincidencias ['SAN MARCOS', '485', 'BLOCK', 'B 303', 'COLINA']  ------  SAN_MARCOS 485 BLOCK B_303 COLINA
# sin coincidencias ['R', 'VARGAS', '758', 'LOS ANDES']  ------  R VARGAS 758 LOS_ANDES
# sin coincidencias ['PJE ESTACION', 'LAUTARO', 'CASA', 'QUILICURA']  ------  PJE_ESTACION LAUTARO CASA QUILICURA
# sin coincidencias ['LOS CHONOS', 'CASA', 'ESQUINA', 'ANGELES']  ------  LOS_CHONOS CASA ESQUINA ANGELES
# ['5', 'ABRIL', '5147-B', 'DPTO42', 'YELCHO', 'ESTACION', 'CENTRAL']  ------  5 ABRIL 5147-B DPTO42 YELCHO ESTACION CENTRAL  -------  Importadora Simba Chile, Avenida 5 de Abril, Barrio Pila del Ganso, Estación Central, Provincia de Santiago, Región Metropolitana de Santiago, 8370261, Chile
# ['STA', 'ISABEL', 'CASA', 'AMARILLA', '1', 'PISO', 'REJA', 'NEGRA', 'CASABLANCA']  ------  STA ISABEL CASA AMARILLA 1 PISO REJA NEGRA CASABLANCA  -------  Santa Isabel, Retiro, Provincia de Linares, Región del Maule, Chile
# ['CAYLLOMA', '501', 'QUINTA', 'TILCOCO', 'OHIGGINS']  ------  CAYLLOMA 501 QUINTA TILCOCO OHIGGINS  -------  Quinta de Tilcoco, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, Chile
# ['CERRO', 'PAILLAHUINTE', '1147', 'MZ-4', 'PANGUIPULLI', 'VILLA', 'CUMBRES']  ------  CERRO PAILLAHUINTE 1147 MZ-4 PANGUIPULLI VILLA CUMBRES  -------  Cerro Paillahuinte, Cumbres de Panguipulli, Panguipulli, Provincia de Valdivia, Región de Los Ríos, Chile
# ['PJ', 'TOULOUSE', '2285', 'P', 'LAS ORQUIDEAS-FRANCIA', 'PADRE', 'HURTADO', 'CALLE', 'LOS SILOS']  ------  PJ TOULOUSE 2285 P LAS_ORQUIDEAS-FRANCIA PADRE HURTADO CALLE LOS_SILOS  -------  Pasaje Toulouse, Padre Hurtado, Provincia de Talagante, Región Metropolitana de Santiago, 9710000, Chile
# sin coincidencias ['BARILOCHE', '2331', 'ARICA', 'ALTO', 'PALENA']  ------  BARILOCHE 2331 ARICA ALTO PALENA
# ['QUINTA', 'NORMAL', '3885', 'DTO', '1408', 'TORRE', 'A']  ------  QUINTA NORMAL 3885 DTO 1408 TORRE A  -------  Ruta normal cerro Catalán, Campamento CMT, Timaukel, Provincia de Tierra del Fuego, Región de Magallanes y de la Antártica Chilena, Chile
# ['JUAN', 'DIOS', 'MAULLIN', 'POBLACION', 'TEN']  ------  JUAN DIOS MAULLIN POBLACION TEN  -------  Hospital San Juan de Dios de La Serena, 916, José Manuel Balmaceda, Barrio Andrés Bello, La Serena, Provincia de Elqui, Región de Coquimbo, 1800798, Chile
# ['CARLOS', 'MUÑOZ', 'PIZARRO', 'SUR', 'VILLA', 'LOS LIBERTADORES', 'COQUIMBO']  ------  CARLOS MUÑOZ PIZARRO SUR VILLA LOS_LIBERTADORES COQUIMBO  -------  Carlos Muñoz Pizarro Sur, Costa Milano, Punta Mira, Coquimbo, Provincia de Elqui, Región de Coquimbo, 1790437, Chile
# sin coincidencias ['UGALPOR', 'LA PANADERIA', 'MELIPILLA']  ------  UGALPOR LA_PANADERIA MELIPILLA
# sin coincidencias ['CAMINO', 'REAL', 'GRANEROS', 'OHIGGINS', 'CHILE']  ------  CAMINO REAL GRANEROS OHIGGINS CHILE
# sin coincidencias ['EL CORAL', '21', 'VILLA', 'QUINTERO']  ------  EL_CORAL 21 VILLA QUINTERO
# sin coincidencias ['BOLIVIA', '2971', 'CIA', 'ALTA', 'LOS CAPELLABES', 'LA SERENA']  ------  BOLIVIA 2971 CIA ALTA LOS_CAPELLABES LA_SERENA
# ['BURGOS', '2096', 'OSORNO', 'CHILE', 'ESQUINA', 'TENERIFE', 'ALTO']  ------  BURGOS 2096 OSORNO CHILE ESQUINA TENERIFE ALTO  -------  Burgos, V Centenario, Rahue, Osorno, Provincia de Osorno, Región de Los Lagos, 5301065, Chile
# ['SAN MARTIN', 'CALLE', 'VILLA', 'FELIX', '#115', 'MAULE']  ------  SAN_MARTIN CALLE VILLA FELIX #115 MAULE  -------  San Martín, Villa San José de Auco, Santuario Santa Teresa de Los Andes, Rinconada, Provincia de Los Andes, Región de Valparaíso, Chile
# ['MONTANDON', '1716', 'DIEGO', 'ALMAGRO']  ------  MONTANDON 1716 DIEGO ALMAGRO  -------  1716, Diego de Almagro, Coyhaique, Provincia de Coyhaique, Región Aysén del General Carlos Ibáñez del Campo, 5952014, Chile
# ['ACCESO', 'A', 'ANGELMO', 'CON', 'PASAJE MARTI', 'PUERTO', 'MONTT']  ------  ACCESO A ANGELMO CON PASAJE_MARTI PUERTO MONTT  -------  Acceso Transbordadores, Población Cumbre Alta, Quinta Hoffmann, Puerto Montt, Provincia de Llanquihue, Región de Los Lagos, 5504052, Chile
# sin coincidencias ['BUSTOS', 'SANTA', 'ROSA', 'CON', 'LOS MAQUIS', 'QUILPUE']  ------  BUSTOS SANTA ROSA CON LOS_MAQUIS QUILPUE
# sin coincidencias ['ACAPULCO', 'OSORNO', 'LOS LAGOS']  ------  ACAPULCO OSORNO LOS_LAGOS
# sin coincidencias ['LA CHACRA', '1073', 'VILLA', 'EL LABRADOR', 'PUENTE', 'ALTO']  ------  LA_CHACRA 1073 VILLA EL_LABRADOR PUENTE ALTO
# ['LIMA', '1485', '1485VILLA', 'PERU', 'LA FLORIDASANTIAGO', 'FLORIDA']  ------  LIMA 1485 1485VILLA PERU LA_FLORIDASANTIAGO FLORIDA  -------  Lima, Villa Perú, La Florida, Provincia de Santiago, Región Metropolitana de Santiago, 8240494, Chile
# sin coincidencias ['AMATISTA', '#', '932']  ------  AMATISTA # 932
# sin coincidencias ['CARMINE', '0249', 'CARCEL', 'MUJERES', 'TEMUCO']  ------  CARMINE 0249 CARCEL MUJERES TEMUCO
# sin coincidencias ['UNION', 'EUROPEA', '101', 'ALTO', 'HOSPICIO']  ------  UNION EUROPEA 101 ALTO HOSPICIO
# sin coincidencias ['RIVOTORTO', '133', 'VILLA', 'SAN FRANCISCO', 'LOS ANGELES']  ------  RIVOTORTO 133 VILLA SAN_FRANCISCO LOS_ANGELES
# sin coincidencias ['MAIPO', '03035', 'PUENTE', 'ALTO']  ------  MAIPO 03035 PUENTE ALTO
# ['CARR', 'AUSTRAL', 'COIHUIN', 'BAJO', 'PUERTO', 'MONTT']  ------  CARR AUSTRAL COIHUIN BAJO PUERTO MONTT  -------  Centro Comercial Carretera Austral, Santa Filomena, Coihuín, Puerto Montt, Provincia de Llanquihue, Región de Los Lagos, Chile
# ['LAS REJAS', 'NORTE', '55', 'DPTO', '2610', 'ESTACION', 'CENTRAL']  ------  LAS_REJAS NORTE 55 DPTO 2610 ESTACION CENTRAL  -------  Las Rejas, Avenida Libertador Bernardo O'Higgins, Villa O'Higgins, Estación Central, Provincia de Santiago, Región Metropolitana de Santiago, 9190847, Chile
# sin coincidencias ['SIN', 'CALLE', 'DALCAHUE', 'LOS LAGOS', 'PUENTE', 'BUTALCURA', 'PASADO', 'CAPILLA']  ------  SIN CALLE DALCAHUE LOS_LAGOS PUENTE BUTALCURA PASADO CAPILLA
# ['AGUAS', 'ABAJO', '3656', '-', '12', 'P', 'MARTA', 'BRUNET', 'PUENTE', 'ALTO', 'EL SAUCE']  ------  AGUAS ABAJO 3656 - 12 P MARTA BRUNET PUENTE ALTO EL_SAUCE  -------  Aguas Abajo, Villa El Sauce, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8181117, Chile
# ['ALONSO', 'ERCILLA', '2257', 'ENTRE', 'DIEGO', 'PORTALES', 'Y', '3', 'SUR', 'IQUIQUE']  ------  ALONSO ERCILLA 2257 ENTRE DIEGO PORTALES Y 3 SUR IQUIQUE  -------  Alonso de Ercilla, Población 27 de Febrero, Amalia, Lebu, Provincia de Arauco, Región del Biobío, Chile
# ['CASAS', 'CHICAS', 'SAN FELIPE']  ------  CASAS CHICAS SAN_FELIPE  -------  Casas Chicas, San Felipe, Provincia de San Felipe de Aconcagua, Región de Valparaíso, 2170000, Chile
# ['PSJ', 'MATILLA', '250', 'PORTESUELO', 'SAN JOAQUIN']  ------  PSJ MATILLA 250 PORTESUELO SAN_JOAQUIN  -------  Matilla, Villa La Unión, San Joaquín, Provincia de Santiago, Región Metropolitana de Santiago, 8940000, Chile
# ['PASAJE ALCALMANUEL DE LA PENA', 'RANCAGUA', 'OHIGGINS', 'BLOQUE', '3', 'DEPTO', '204']  ------  PASAJE_ALCALMANUEL_DE_LA_PENA RANCAGUA OHIGGINS BLOQUE 3 DEPTO 204  -------  Rancagua, Matilla, Pica, Provincia del Tamarugal, Región de Tarapacá, Chile
# sin coincidencias ['CAM', 'EL VERGEL', 'DEPTO', '1', 'VALPARAISO']  ------  CAM EL_VERGEL DEPTO 1 VALPARAISO
# sin coincidencias ['SAN NESTOR', 'DEPARTAMENTO', 'LOS ANDES']  ------  SAN_NESTOR DEPARTAMENTO LOS_ANDES
# ['VICTORIA', '779', 'CASA 5', 'SANTIAGO']  ------  VICTORIA 779 CASA_5 SANTIAGO  -------  779, Victoria, Barrio Matta Sur, Santiago, Provincia de Santiago, Región Metropolitana de Santiago, 8360481, Chile
# ['PASAJE PAPA', 'DAMASO', '445', 'VILLA', 'JUAN', 'PABLO', 'SAN FELIPE']  ------  PASAJE_PAPA DAMASO 445 VILLA JUAN PABLO SAN_FELIPE  -------  Museo Oceanográfico, Rambla República de Chile, Buceo, Montevideo, 11600, Uruguay
# ['UNO', 'PONIENTE', '7', 'VILLA', 'PUAUCHO', 'SAN', 'JUAN DE LA COSTA', 'SECTOR', 'ALTO', 'OSORNO']  ------  UNO PONIENTE 7 VILLA PUAUCHO SAN JUAN_DE_LA_COSTA SECTOR ALTO OSORNO  -------  Pasaje Tepas Uno Poniente, Villa El Pangue, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8153644, Chile
# sin coincidencias ['PASAJE RADIUM', '861', 'CONCEPCION', 'BIOBIO', 'CENTRO', 'DE']  ------  PASAJE_RADIUM 861 CONCEPCION BIOBIO CENTRO DE
# sin coincidencias ['PJE OMAN', 'BARRIO', 'SANTA', 'ELENA', 'VALDIVIA']  ------  PJE_OMAN BARRIO SANTA ELENA VALDIVIA
# sin coincidencias ['PJE', 'LOS PLUMBAGOS']  ------  PJE LOS_PLUMBAGOS
# ['ZAJON', 'SECO', 'PUCON', 'LA ARAUCANIA', 'ARRIAGADA', 'KM', '1', '3', 'LT', 'A', '1-2']  ------  ZAJON SECO PUCON LA_ARAUCANIA ARRIAGADA KM 1 3 LT A 1-2  -------  Chile
# ['SECTOR', 'ANTILHUE', 'CENTRO', '0', 'MALALHUE', 'LANCO']  ------  SECTOR ANTILHUE CENTRO 0 MALALHUE LANCO  -------  Sector Centro, Los Lagos, Provincia de Valdivia, Región de Los Ríos, Chile
# ['PJ', 'CORBETA2954', 'VILLA', 'SANTA', 'ESTER', 'PUENTE', 'ALTO']  ------  PJ CORBETA2954 VILLA SANTA ESTER PUENTE ALTO  -------  Villa Santa Ester, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8207897, Chile
# sin coincidencias ['EL ROBLE', '87', 'VILLA', 'PADRE', 'HURTADO']  ------  EL_ROBLE 87 VILLA PADRE HURTADO
# ['C', 'ADRIANA', 'GARCIA', 'IBAÑEZ', 'CANCHAS', 'SINTETICAS', 'EL MONUMENTAL', 'SAN JAVIER']  ------  C ADRIANA GARCIA IBAÑEZ CANCHAS SINTETICAS EL_MONUMENTAL SAN_JAVIER  -------  Adriana García Ibáñez, Villa Carolina Salgado, Chanquicó Sur, San Javier, Provincia de Linares, Región del Maule, Chile
# ['PATRICIO', 'LYNCH', '785', 'CASA', '#', '3', 'SEGUNDO', 'PISO', 'CAMPAMENTO', 'FAMILIAS', 'UNIDAS', 'ANTOFAGASTA']  ------  PATRICIO LYNCH 785 CASA # 3 SEGUNDO PISO CAMPAMENTO FAMILIAS UNIDAS ANTOFAGASTA  -------  Patricio Lynch, Campameto Familias Unidas, Antofagasta, Provincia de Antofagasta, Región de Antofagasta, 1270199, Chile
# ['BLANCO', 'QUILPUE', '926', 'NUMERO', '11']  ------  BLANCO QUILPUE 926 NUMERO 11  -------  Blanco, Peñablanca, Villa Alemana, Provincia de Marga Marga, Región de Valparaíso, 6500000, Chile
# sin coincidenciassin coincidencias ['PABLO', 'NERUDA', 'CABAÑAS', 'BLANCAS', 'PEDRO', 'VERA', 'CASTRO']  ------  PABLO NERUDA CABAÑAS BLANCAS PEDRO VERA CASTRO
#  ['LYNCH', 'NTE', 'CASA', 'A', 'LA REINA']  ------  LYNCH NTE CASA A LA_REINA
# ['CAMINO', 'INTERIOR', 'PARC-95', 'SITIO', '8', 'EX', 'FUNDO', 'EL TABO', 'SAN ANTONIO']  ------  CAMINO INTERIOR PARC-95 SITIO 8 EX FUNDO EL_TABO SAN_ANTONIO  -------  Camino Circunvalacion Santa Luisa, El Tabo, Provincia de San Antonio, Región de Valparaíso, 2690000, Chile
# ['FORESTAL', '1086', 'ENTRADA', 'POR', 'VICUÑA', 'MACKENA', 'NO', 'HOMOLOGADO']  ------  FORESTAL 1086 ENTRADA POR VICUÑA MACKENA NO HOMOLOGADO  -------  Liceo Agricola y Forestal Suizo La Providencia, Ruta R-826, Chanco Mariguala, Traiguén, Provincia de Malleco, Región de la Araucanía, 4730000, Chile
# ['CAMPAMENTO', 'VILLA', 'DIGNIDAD', 'CALLE', 'LIBERTAD', 'N65', 'COLINA']  ------  CAMPAMENTO VILLA DIGNIDAD CALLE LIBERTAD N65 COLINA  -------  Campamento Villa Esfuerzo, Mejillones, Provincia de Antofagasta, Región de Antofagasta, 1310000, Chile
# sin coincidencias ['MINERVA', '3021', 'ASUNCION', 'CON', '3', 'PONIENTE', 'MAIPU']  ------  MINERVA 3021 ASUNCION CON 3 PONIENTE MAIPU
# sin coincidencias ['F DEL CAMPO', 'B7', '1207', 'DEPTO', '305', 'COLINA']  ------  F_DEL_CAMPO B7 1207 DEPTO 305 COLINA
# sin coincidencias ['ESTEBAN', 'GOMEZ', 'CASA', 'MADERA', 'OLIVAR']  ------  ESTEBAN GOMEZ CASA MADERA OLIVAR
# sin coincidencias ['SEVERO', 'COFRE', 'CASA', 'BLANCA', 'GRAN#983', 'CASTRO']  ------  SEVERO COFRE CASA BLANCA GRAN#983 CASTRO
# sin coincidencias ['SAN LUIS', '872', 'PABLO', 'PUDAHUEL']  ------  SAN_LUIS 872 PABLO PUDAHUEL
# ['LITORAL', 'BELLAVISTA', 'HOLANDA', 'CALLE', 'BLOCK', '961', 'DEPARTAMENTO', '27', 'SAN ANTONIO']  ------  LITORAL BELLAVISTA HOLANDA CALLE BLOCK 961 DEPARTAMENTO 27 SAN_ANTONIO  -------  Litoral, Población Bellavista, San Antonio, Provincia de San Antonio, Región de Valparaíso, Chile
# ['RAMON', 'BARROS', 'LUCO', 'CASA', 'ROJA', 'CON', 'REJA', 'NEGRA', '7938', 'SAN']  ------  RAMON BARROS LUCO CASA ROJA CON REJA NEGRA 7938 SAN  -------  Ramón Barros Luco, Nueva Patagonia, Natales, Provincia de Última Esperanza, Región de Magallanes y de la Antártica Chilena, 6160000, Chile
# sin coincidencias ['MAR', 'LOS SARGAZOS', '662', 'LA SERENA']  ------  MAR LOS_SARGAZOS 662 LA_SERENA
# sin coincidencias ['SALMERON', '137', 'ARGENTINA', 'E', 'ITALIA', 'LAMPA']  ------  SALMERON 137 ARGENTINA E ITALIA LAMPA
# ['VOLCAN', 'MIRADOR', '265', 'LAGO', 'RANCO']  ------  VOLCAN MIRADOR 265 LAGO RANCO  -------  Volcan Tolguaca, Los Mañios, Futrono, Provincia de Ranco, Región de Los Ríos, Chile
# ['HUELLAHUE', '00', 'PANGUIPULLI', 'LADO', 'NEGOCIO', 'TRINY']  ------  HUELLAHUE 00 PANGUIPULLI LADO NEGOCIO TRINY  -------  Huellahue, Panguipulli, Provincia de Valdivia, Región de Los Ríos, Chile
# ['J', 'BAKER', '1885', 'LOS ANDES', 'VILLA', 'EL HORIZONTE', 'JUAN']  ------  J BAKER 1885 LOS_ANDES VILLA EL_HORIZONTE JUAN  -------  Los Andes, Villa Cordillera, Machalí, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, 2910060, Chile
# ['CALLEJON', 'SOLIS', 'TENO', 'MAULE', 'CURICO']  ------  CALLEJON SOLIS TENO MAULE CURICO  -------  Callejón, Estadio, Hualañé, Provincia de Curicó, Región del Maule, Chile
# ['LUIS', 'ALVAREZ', '2739', 'PABLO', 'NERUDA', 'VALDIVIA']  ------  LUIS ALVAREZ 2739 PABLO NERUDA VALDIVIA  -------  Luis Muñoz, Población Membrillar, Retiro, Provincia de Linares, Región del Maule, Chile
# sin coincidencias ['EL JARDIN', 'OTE', 'PLAZA', 'LAS PETRAS', 'CONCON']  ------  EL_JARDIN OTE PLAZA LAS_PETRAS CONCON
# ['LAGUNA', 'SAN RAFAEL', 'REGION', 'XI', 'CHILE', 'EN', 'PUERTO', 'AYSEN']  ------  LAGUNA SAN_RAFAEL REGION XI CHILE EN PUERTO AYSEN  -------  Laguna San Rafael, Aysén, Provincia de Aysén, Región Aysén del General Carlos Ibáñez del Campo, Chile
# ['BELLAVISTA', 'CASA1147', 'POBLACION', 'PASAJE RIO', 'HUASCO', 'LOS ANDES']  ------  BELLAVISTA CASA1147 POBLACION PASAJE_RIO HUASCO LOS_ANDES  -------  Chile, Doña Pilar 1, Parral, Provincia de Linares, Región del Maule, 3630000, Chile
# ['RIO', 'TOLTEN', '36', 'L38', 'NOGALES', 'POB', 'UNION', 'LA CALERA']  ------  RIO TOLTEN 36 L38 NOGALES POB UNION LA_CALERA  -------  Río Toltén, Artificio, La Calera, Provincia de Quillota, Región de Valparaíso, 2290000, Chile
# ['MARIQUINA', '990', 'TORRE', '1', '401', 'CONDOMINIO', 'LAS PRADERAS', 'PASADO', 'SUPERMERCADO', 'LILY']  ------  MARIQUINA 990 TORRE 1 401 CONDOMINIO LAS_PRADERAS PASADO SUPERMERCADO LILY  -------  Condominio Las Praderas, Tira Larga, Callejones, San Vicente de Tagua Tagua, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, 2970000, Chile
# sin coincidencias ['PARSIFAL', '6369', 'POBLACION', 'LA CASTRINA', 'SAN JOAQUIN']  ------  PARSIFAL 6369 POBLACION LA_CASTRINA SAN_JOAQUIN
# sin coincidencias ['ALEJANDRO', 'CORCUERA', 'REUMEN', 'PAILLACO']  ------  ALEJANDRO CORCUERA REUMEN PAILLACO
# sin coincidencias ['ALMTE', 'JOSE', 'LA TORRE', '2406', 'ANTOFAGASTA']  ------  ALMTE JOSE LA_TORRE 2406 ANTOFAGASTA
# ['CLAUDIO', 'NAVARRETE', 'PINO', 'CASA 1074', 'VILLA', 'NACIMIENTO', 'PASAJE']  ------  CLAUDIO NAVARRETE PINO CASA_1074 VILLA NACIMIENTO PASAJE  -------  Pasaje Claudio Navarrete Pino, Villa Nacimiento, Nacimiento, Provincia de Bío-Bío, Región del Biobío, 4550000, Chile
# ['CAM', 'A', 'RINCONADA', 'PI946', 'MAIPU']  ------  CAM A RINCONADA PI946 MAIPU  -------  Camino a Rinconada, Barrio Templo Votivo, Maipú, Provincia de Santiago, Región Metropolitana de Santiago, 9252311, Chile
# sin coincidencias ['AVDA', 'QUILVO', 'ROMERAL', 'MAULE']  ------  AVDA QUILVO ROMERAL MAULE
# ['ROSA', 'ELENA', '874', 'POBLACION', 'MEZA', 'PADRE', 'LAS CASAS']  ------  ROSA ELENA 874 POBLACION MEZA PADRE LAS_CASAS  -------  Rosa Elena, Población Meza, Padre Las Casas, Provincia de Cautín, Región de la Araucanía, 4850000, Chile
# ['PASO', 'PEHUENCHE', '392', 'SAN CLEMENTE', 'MAULE', 'VALLES DEL CASA', 'DETRAS', 'COLEGIO', 'ANDRES', 'TALCA']  ------  PASO PEHUENCHE 392 SAN_CLEMENTE MAULE VALLES_DEL_CASA DETRAS COLEGIO ANDRES TALCA  -------  Paso Pehuenche, San Clemente, Provincia de Talca, Región del Maule, Chile
# sin coincidencias ['RIO', 'JANEIRO', '10011002', 'LAMPA', 'CHILE', 'PASADO', 'LOS ESPINO']  ------  RIO JANEIRO 10011002 LAMPA CHILE PASADO LOS_ESPINO
# sin coincidencias ['PJE', 'LOS MIRLOS', 'NUMERO', 'CASA 0434', 'TEMUCO']  ------  PJE LOS_MIRLOS NUMERO CASA_0434 TEMUCO
# sin coincidencias ['CJON', 'EL CONSUELO', 'PASAJE WARIMANQUE', 'SALAMANCA']  ------  CJON EL_CONSUELO PASAJE_WARIMANQUE SALAMANCA
# ['SEPTIMA', '374', 'E', 'REÑACA', 'ALTO', 'VIÑA', 'DEL', 'MAR']  ------  SEPTIMA 374 E REÑACA ALTO VIÑA DEL MAR  -------  Avenida Séptima, Villa La Cruz, Reñaca Alto, Viña del Mar, Provincia de Valparaíso, Región de Valparaíso, Chile
# ['MANUEL', 'TOLEDO', 'CALLE', 'MANZANAL', 'POBLACION', 'CORVI', 'CHICA', 'PUERTO', 'VARAS']  ------  MANUEL TOLEDO CALLE MANZANAL POBLACION CORVI CHICA PUERTO VARAS  -------  Pasaje Manuel Toledo, Población Antonio Varas, Puerto Varas, Provincia de Llanquihue, Región de Los Lagos, 5550988, Chile
# ['ARGENTINA', '654', 'ENTRE', 'BARRO', 'LUCO', 'Y', 'SALVADOR', 'ALLENPUENTE', 'ALTO']  ------  ARGENTINA 654 ENTRE BARRO LUCO Y SALVADOR ALLENPUENTE ALTO  -------  Chile, Sacachispas, Chajarí, Distrito Mandisoví, Departamento Federación, Entre Ríos, E3228EZO, Argentina
# ['A', 'CALCURRUPE', 'BAJO', 'SIN', 'NUMERO', 'LAGO', 'RANCO']  ------  A CALCURRUPE BAJO SIN NUMERO LAGO RANCO  -------  Calcurrupe Bajo, Lago Ranco, Provincia de Ranco, Región de Los Ríos, 5180000, Chile
# ['OCHO', 'NTE', '1480', 'CASA', 'A', 'MITAD', 'PASAJE ENTRE', 'LAS CALLES', 'CENTRAL', 'Y', 'AZTECA', 'PEDRO', 'AGUIRRE', 'CERDA']  ------  OCHO NTE 1480 CASA A MITAD PASAJE_ENTRE LAS_CALLES CENTRAL Y AZTECA PEDRO AGUIRRE CERDA  -------  Avenida Presidente Jorge Alessandri Rodríguez / Pasaje Ocho, Avenida Presidente Jorge Alessandri Rodríguez, Manuel Bulnes Sur, Punta Arenas, Provincia de Magallanes, Región de Magallanes y de la Antártica Chilena, 6200537, Chile
# ['RECOLETA', '676', 'ENTRE', 'OLIVOS', 'Y', 'RAIMUNDO', 'CHARLIN']  ------  RECOLETA 676 ENTRE OLIVOS Y RAIMUNDO CHARLIN  -------  Escuela nro. 14 "República de Chile", Avenida España, Recoleta, Asunción, Distrito Capital, Región Oriental, 001207, Paraguay / Paraguái
# sin coincidencias ['ESPERANZA', '2246', '11', 'SAN RAMON']  ------  ESPERANZA 2246 11 SAN_RAMON
# ['VILLA', 'LA ESPERANZA', '70', 'SE', '1464', '6', '011429', 'CORRALONES', 'TALCA']  ------  VILLA LA_ESPERANZA 70 SE 1464 6 011429 CORRALONES TALCA  -------  Villa La Esperanza, Comunidad Nahuelgual, Quepe, Freire, Provincia de Cautín, Región de la Araucanía, Chile
# ['PA', 'DOS', '3830', 'CONJUNTO', 'HABITACIONAL', 'EL BORO', 'ALTO', 'HOSPICIO', 'IQUIQUE']  ------  PA DOS 3830 CONJUNTO HABITACIONAL EL_BORO ALTO HOSPICIO IQUIQUE  -------  Chile, Alto Hospicio, Provincia de Iquique, Región de Tarapacá, 1130000, Chile
# sin coincidencias ['SAN ANTONIO', 'QUELLON', 'LOS LAGOS']  ------  SAN_ANTONIO QUELLON LOS_LAGOS
# ['VOLCAN', 'CORCOVADO', 'RANCAGUA', 'OHIGGINS', 'VILLA', 'HORIZONTE']  ------  VOLCAN CORCOVADO RANCAGUA OHIGGINS VILLA HORIZONTE  -------  Volcán Corcovado, Villa Camino Real, Rancagua, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, 2912158, Chile
# sin coincidencias ['DIEGO', 'PORTALES', 'OFICINA', 'ESVAL', 'CASABLANCA']  ------  DIEGO PORTALES OFICINA ESVAL CASABLANCA
# ['PASAJE REY', 'DAVID', '34', 'LOTA', 'BIOBIO']  ------  PASAJE_REY DAVID 34 LOTA BIOBIO  -------  Lota, Provincia de Concepción, Región del Biobío, Chile
# ['SALAS', '49', 'SECTOR', 'ARENAL', 'CASA', 'INTERIOR', 'TALCAHUANO']  ------  SALAS 49 SECTOR ARENAL CASA INTERIOR TALCAHUANO  -------  Manuel de Salas, Población COPIVEM, Gómez Carreño, Viña del Mar, Provincia de Valparaíso, Región de Valparaíso, 2571190, Chile
# ['C', 'NUEVA', 'UNO', 'SUR', 'CASA', 'VERPUDAHUEL']  ------  C NUEVA UNO SUR CASA VERPUDAHUEL  -------  Pinto Sur, Villa Estadio, Gorbea, Provincia de Cautín, Región de la Araucanía, Chile
# ['SEVILLA', '1820', 'POB', 'QUINTO', 'CENTENARIO', 'OSORNO']  ------  SEVILLA 1820 POB QUINTO CENTENARIO OSORNO  -------  Sevilla, Población Centenario, Rancagua, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, 2852046, Chile
# ['NONATO', 'COO', '800', 'VILLA', 'NEVADIS DEL MAIPO', 'PUENTE', 'ALTO']  ------  NONATO COO 800 VILLA NEVADIS_DEL_MAIPO PUENTE ALTO  -------  Nonato Coo, Villa Los Prados, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8220451, Chile
# ['PEDRO', 'VALDIVIA', 'CASA', 'SAN BERNARDO']  ------  PEDRO VALDIVIA CASA SAN_BERNARDO  -------  Casa de Pedro de Valdivia, Toconao, Población Licancabur, Condeduque, San Pedro de Atacama, Provincia de El Loa, Región de Antofagasta, 1410000, Chile
# ['SIN', 'CALLE', 'CONCEPCION', 'BIOBIO', 'PON', 'EDUARDO', 'FREI', 'MAGDALENA', '269']  ------  SIN CALLE CONCEPCION BIOBIO PON EDUARDO FREI MAGDALENA 269  -------  Aurora de Chile, Población Los Notros, Chiguayante, Provincia de Concepción, Región del Biobío, 4100812, Chile
# ['RIQUELME', '1959', 'VILLA', 'POBLACION', 'LA BANDERA', 'SAN RAMON']  ------  RIQUELME 1959 VILLA POBLACION LA_BANDERA SAN_RAMON  -------  Riquelme, Población La Bandera, San Ramón, Provincia de Santiago, Región Metropolitana de Santiago, 8870068, Chile
# ['ESMERALDA', '772', 'DP', '1008', 'SANTIAGO']  ------  ESMERALDA 772 DP 1008 SANTIAGO  -------  Parceleros Sector 2 de Popeta, Las Palmeras Poniente, Melipilla, Provincia de Melipilla, Región Metropolitana de Santiago, Chile
# ['SANTA', 'TERESA', 'LOS ANDES', 'LA ESCUADRA', '3', '#1187', 'RADIOTAXIS', 'TAXCOM', 'SAN FELIPE']  ------  SANTA TERESA LOS_ANDES LA_ESCUADRA 3 #1187 RADIOTAXIS TAXCOM SAN_FELIPE  -------  Santuario Santa Teresa de Los Andes, Rinconada, Provincia de Los Andes, Región de Valparaíso, Chile
# ['CALLE', 'VEINTICINCO', 'NORTE', 'TALCA', 'MAULE', 'VILLA', 'DON', 'BENITO']  ------  CALLE VEINTICINCO NORTE TALCA MAULE VILLA DON BENITO  -------  Plaza 26 Norte, Villa Don Benito, Lircay, Talca, Provincia de Talca, Región del Maule, Chile
# ['CORONEL', '7765', 'AVDA', 'COMBARBALA', 'LA GRANJA']  ------  CORONEL 7765 AVDA COMBARBALA LA_GRANJA  -------  Combarbalá, Población Malaquías Concha, La Granja, Provincia de Santiago, Región Metropolitana de Santiago, 8231472, Chile
# ['PA', 'LAS GOLONDRINAS', '620', 'LOTEO', 'VILLA', 'JERUSALEM', 'MONTE', 'PATRIA', 'OVALLE']  ------  PA LAS_GOLONDRINAS 620 LOTEO VILLA JERUSALEM MONTE PATRIA OVALLE  -------  Ruta D-55, Las Siete Casas, Los Litres Sur, El Palqui, Monte Patria, Provincia de Limarí, Región de Coquimbo, 1880000, Chile
# ['EL MOLINO', 'PASAJE 5', 'N 312', 'PUTAENDO']  ------  EL_MOLINO PASAJE_5 N_312 PUTAENDO  -------  Pasaje 5, Villa Los Jazmines, Granalla, Putaendo, Provincia de San Felipe de Aconcagua, Región de Valparaíso, Chile
# ['3', 'MAYO', '2685', 'TR', 'F', 'DP', '503', 'INDEPENDENCIA']  ------  3 MAYO 2685 TR F DP 503 INDEPENDENCIA  -------  Chileweg, Ganzenbühl, Seen, Gotzenwil, Winterthur, Bezirk Winterthur, Zürich, 8405, Schweiz/Suisse/Svizzera/Svizra
# sin coincidencias ['CAPITAN', 'REBOLLEDO', 'N38']  ------  CAPITAN REBOLLEDO N38
# ['VIOLETA', 'PARRA', 'POBLACION', 'LA ESPERANZA', 'TUCAPEL']  ------  VIOLETA PARRA POBLACION LA_ESPERANZA TUCAPEL  -------  Banco Estado, Avenida Violeta Parra, Comité Licarayén, Alerce, Puerto Montt, Provincia de Llanquihue, Región de Los Lagos, Chile
# ['BLANCA', 'OSORIO', 'GODOY', 'PJE LEON', 'XIII', '567', 'FERIA', 'LAS PULGAS', 'MEDIA', 'HACIENDA']  ------  BLANCA OSORIO GODOY PJE_LEON XIII 567 FERIA LAS_PULGAS MEDIA HACIENDA  -------  Estrella Blanca, La Victoria, Pedro Aguirre Cerda, Provincia de Santiago, Región Metropolitana de Santiago, 8480294, Chile
# sin coincidencias ['PJE RIO', 'TENO', 'CASA', 'ESQUINA', 'CONSTITUCION']  ------  PJE_RIO TENO CASA ESQUINA CONSTITUCION
# ['S-61', 'MELIPEUCO', 'LA ARAUCANIA', 'S', '61', 'ESCUELA', 'DAHUELHUE']  ------  S-61 MELIPEUCO LA_ARAUCANIA S 61 ESCUELA DAHUELHUE  -------  Camino Termas de Molulco, Comunidad Francisco Huenchumil, Melipeuco, Provincia de Cautín, Región de la Araucanía, Chile
# ['SAN JAVIER', 'CASA', 'LOS', 'VIÑEDOS', 'MAULE']  ------  SAN_JAVIER CASA LOS VIÑEDOS MAULE  -------  San Javier, Vaticano, Curicó, Provincia de Curicó, Región del Maule, 3341353, Chile
# sin coincidencias ['JULIO', 'ENRIQUE', 'FENNER', '103C', 'VALPARAISO']  ------  JULIO ENRIQUE FENNER 103C VALPARAISO
# ['PRESIDENTE', 'JOSE', 'MANUEL', 'BALMACEDA', '111', 'COLBUN', 'MAULE', 'ULTIMO', 'PASAJE CASA', 'ESQUINA']  ------  PRESIDENTE JOSE MANUEL BALMACEDA 111 COLBUN MAULE ULTIMO PASAJE_CASA ESQUINA  -------  Presidente José Manuel Balmaceda, San Francisco, Colbún, Provincia de Linares, Región del Maule, 3610000, Chile
# sin coincidencias ['YUCATAN', '641', 'VILLA', 'LAS AMERICAS', 'LOS ANGELES']  ------  YUCATAN 641 VILLA LAS_AMERICAS LOS_ANGELES
# ['PJE DOS', '105', 'POBLACION', 'YUNGAY', 'LA GRANJA']  ------  PJE_DOS 105 POBLACION YUNGAY LA_GRANJA  -------  Población La Granja de Popeta, Popeta Puente Negro, Popeta, Rengo, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, Chile
# ['PJE', 'EL ROSAL', 'VILLA', 'LOS PALTOS', 'NUMERO', '37', 'PADRE', 'HURTADO']  ------  PJE EL_ROSAL VILLA LOS_PALTOS NUMERO 37 PADRE HURTADO  -------  Villa Alegre, Villa Azul, La Granja, Provincia de Santiago, Región Metropolitana de Santiago, 8870068, Chile
# sin coincidencias ['TUBUL', 'ARAUCO', 'BIOBIO', 'SECTOR', 'LOS PUENTES']  ------  TUBUL ARAUCO BIOBIO SECTOR LOS_PUENTES
# sin coincidencias ['JULIO', 'ECHEVARRIA']  ------  JULIO ECHEVARRIA
# ['CARLOS', 'SPANO', '2693', 'COSTA', 'RICA', 'CON', 'CONCHALI']  ------  CARLOS SPANO 2693 COSTA RICA CON CONCHALI  -------  2693, Carlos Spano, Villa Doña Javiera, Conchalí, Provincia de Santiago, Región Metropolitana de Santiago, 8380741, Chile
# ['PEDRO', 'VALDIVIA', '2348', 'CASA', 'CON', 'PORTON', 'CAFE', 'A', 'LADO', 'UNA', 'COCINERIA', 'Y', 'ALMACEN', 'CALAMA']  ------  PEDRO VALDIVIA 2348 CASA CON PORTON CAFE A LADO UNA COCINERIA Y ALMACEN CALAMA  -------  Pedro de Valdivia, Chinchorro, Arica, Provincia de Arica, Región de Arica y Parinacota, 1020759, Chile
# ['SAN PEDRO', '229', 'NEGOCIO', 'ESQUINA', 'PUENTE', 'ALTO']  ------  SAN_PEDRO 229 NEGOCIO ESQUINA PUENTE ALTO  -------  229, San Pedro, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8165076, Chile
# ['JUAN', 'CRISTOBAL', 'BLOCK', '20', 'DPTO', '414', 'RECOLETA']  ------  JUAN CRISTOBAL BLOCK 20 DPTO 414 RECOLETA  -------  Juan Cristóbal, Población 28 de Octubre, Huechuraba, Provincia de Santiago, Región Metropolitana de Santiago, 9362427, Chile
# ['JUAN', 'ANTONIO', 'RIOS', 'CALLE', '1705', 'BLOCK', '1', 'DEPTO', '401', 'CORONEL']  ------  JUAN ANTONIO RIOS CALLE 1705 BLOCK 1 DEPTO 401 CORONEL  -------  Juan Antonio Rios, Población Santa Elena, Antihuala, Los Álamos, Provincia de Arauco, Región del Biobío, 4380000, Chile
# sin coincidencias ['CENTENARIO', 'MED216878', 'EL TABO']  ------  CENTENARIO MED216878 EL_TABO
# ['VILLA', 'GENEROSA', 'PUNTA', 'ARENAS', 'MAGALLANES', 'PARCELA', '24B']  ------  VILLA GENEROSA PUNTA ARENAS MAGALLANES PARCELA 24B  -------  Villa Generosa, Punta Arenas, Provincia de Magallanes, Región de Magallanes y de la Antártica Chilena, 6200537, Chile
# ['TURMALINA', '574', 'SAN', 'PEDRO DE LA PAZ', 'BIOBIO', 'PIEDRA', 'FRANCIA']  ------  TURMALINA 574 SAN PEDRO_DE_LA_PAZ BIOBIO PIEDRA FRANCIA  -------  San Pedro de la Paz, Provincia de Concepción, Región del Biobío, Chile
# sin coincidencias ['SANTIAGO', 'CONCHA', 'CASA', '#1316']  ------  SANTIAGO CONCHA CASA #1316
# sin coincidencias ['POLONIA', '2239', '2', 'CERRILLOS']  ------  POLONIA 2239 2 CERRILLOS
# ['VILLA', 'LOS PEUMOS', '3', 'CALLEJON', 'ULTIMA', 'CASA', 'ANDES']  ------  VILLA LOS_PEUMOS 3 CALLEJON ULTIMA CASA ANDES  -------  Villa Los Peumos, La Florida, Provincia de Santiago, Región Metropolitana de Santiago, 8250736, Chile
# sin coincidencias ['FARUC', 'AGUAD', 'PEREZ', 'CASA 2008', 'CABILDO']  ------  FARUC AGUAD PEREZ CASA_2008 CABILDO
# ['PASAJE DIECISIETE', 'Y', 'MEDIO', 'NORTE', '1383', 'TALCA', 'MAULE', 'POBLACION', 'CANCHA', 'RAYADA']  ------  PASAJE_DIECISIETE Y MEDIO NORTE 1383 TALCA MAULE POBLACION CANCHA RAYADA  -------  Rotonda 5 y Medio Poniente B, Barrio San Agustín, Barrio Norte, Talca, Provincia de Talca, Región del Maule, Chile
# ['55', '-', '6640', 'LO', 'ESPEJO']  ------  55 - 6640 LO ESPEJO  -------  Villa Lo Espejo 2, El Bosque, Provincia de Santiago, Región Metropolitana de Santiago, 8000146, Chile
# ['PASAJE PALI', 'AIKE', '1428', 'BOSQUE', 'SAN CARLOS', 'COQUIMBO']  ------  PASAJE_PALI AIKE 1428 BOSQUE SAN_CARLOS COQUIMBO  -------  Parque Pali Aike, Bosque San Carlos, Tierras Blancas, Coquimbo, Provincia de Elqui, Región de Coquimbo, 1721411, Chile
# sin coincidencias ['PJE GIRASOL', 'MINIMARKET', 'FLAKITA', 'PADRE', 'HURTADO']  ------  PJE_GIRASOL MINIMARKET FLAKITA PADRE HURTADO
# ['AVENIDA', 'SANTA', 'ROSA', 'DEPARTAMENTO', '11', 'BLOK', '16', 'VILLA', 'ESPERANZA', 'SAN RAMON']  ------  AVENIDA SANTA ROSA DEPARTAMENTO 11 BLOK 16 VILLA ESPERANZA SAN_RAMON  -------  Chile, Barrio Residencial Santa Rosa, Seccional 19na, Corrientes, Departamento Capital, Corrientes, W3400BSN, Argentina
# sin coincidencias ['ARGENTINA', '2061', 'PALMERA', 'SAN RAMON']  ------  ARGENTINA 2061 PALMERA SAN_RAMON
# ['SIN', 'CALLE', 'LOS TAPIAS', 'CARRETERA', 'COMUNA', 'MONTE', 'PATRIA', 'CHAÑARAL', 'ALTO']  ------  SIN CALLE LOS_TAPIAS CARRETERA COMUNA MONTE PATRIA CHAÑARAL ALTO  -------  O'Higgins, Cerro Alegre, Chañaral Alto, Monte Patria, Provincia de Limarí, Región de Coquimbo, Chile
# sin coincidencias ['NICANOR', 'MOLINARE', '149', 'QUILLOTA']  ------  NICANOR MOLINARE 149 QUILLOTA
# ['VICUNA', 'MACKENNA', 'TALCAHUANO', 'BIOBIO', 'CASA', 'ESQUINA']  ------  VICUNA MACKENNA TALCAHUANO BIOBIO CASA ESQUINA  -------  Benjamín Vicuña Mackenna, Gaete, Talcahuano, Provincia de Concepción, Región del Biobío, 4261172, Chile
# ['PJE ARTURO', 'GORDON', 'DEPTO', '36', 'POBLACION', 'PEDRO', 'LIRA', 'PUENTE', 'ALTO']  ------  PJE_ARTURO GORDON DEPTO 36 POBLACION PEDRO LIRA PUENTE ALTO  -------  Pasaje Arturo Gordon, Población Pedro Lira, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8181117, Chile
# sin coincidencias ['ESTANISLAO DEL CANTO', '120', 'RINCONADA']  ------  ESTANISLAO_DEL_CANTO 120 RINCONADA
# ['PJE 2', 'VILLA', 'EL BOSQUE', 'LICANTEN']  ------  PJE_2 VILLA EL_BOSQUE LICANTEN  -------  Pje. Jorge M. Ivelic, Altos del Bosque, Punta Arenas, Provincia de Magallanes, Región de Magallanes y de la Antártica Chilena, 6210314, Chile
# ['CALLE', 'AVENIDA', 'CUARTA', 'TERRAZA', 'CONDOMINIO', 'ALTA', 'VISTA', '1840', 'CASA 32', 'PUERTO', 'MONTT']  ------  CALLE AVENIDA CUARTA TERRAZA CONDOMINIO ALTA VISTA 1840 CASA_32 PUERTO MONTT  -------  Avenida Cuarta Terraza, Condominio Alta Vista, Puerto Montt, Provincia de Llanquihue, Región de Los Lagos, 5507138, Chile
# ['C', '5', '1806', 'VILLA', 'EL', 'RETOÑO', 'QUILLOTA']  ------  C 5 1806 VILLA EL RETOÑO QUILLOTA  -------  Calle 5, Villa Lagos de Chile, Chiguayante, Provincia de Concepción, Región del Biobío, 4100812, Chile
# sin coincidencias ['PASAJE LINCOYAN', '67', 'REQUINOA', 'OHIGGINS']  ------  PASAJE_LINCOYAN 67 REQUINOA OHIGGINS
# ['EL RODEO', '01426', 'B-C', '-', '304', 'COND', 'DON', 'CRISTIAN', 'PUENTE', 'ALTO']  ------  EL_RODEO 01426 B-C - 304 COND DON CRISTIAN PUENTE ALTO  -------  El Rodeo, Villa Jardines del Rodeo, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8167426, Chile
# ['SEIS', 'Y', 'MEDIO', 'PONIENTE', 'B 1067', 'TALCA', 'MAULE']  ------  SEIS Y MEDIO PONIENTE B_1067 TALCA MAULE  -------  Rotonda 5 y Medio Poniente B, Barrio San Agustín, Barrio Norte, Talca, Provincia de Talca, Región del Maule, Chile
# ['FLORENCIA', '1547', 'CASA', '2', 'PISOS', 'MINIMARKET', 'ABAJO', 'LA CERRO', 'NAVIA']  ------  FLORENCIA 1547 CASA 2 PISOS MINIMARKET ABAJO LA_CERRO NAVIA  -------  Florencia, Villa 4 de Septiembre, Cerro Navia, Provincia de Santiago, Región Metropolitana de Santiago, 9010290, Chile
# ['AUGUSTA', 'VELASQUEZ', '1136', 'VILLA', 'LA CRUZ', 'REÑACA', 'ALTO', 'VIÑA', 'DEL', 'MAR']  ------  AUGUSTA VELASQUEZ 1136 VILLA LA_CRUZ REÑACA ALTO VIÑA DEL MAR  -------  Avenida Agusto Velásquez, Las Tomas, Reñaca Alto, Viña del Mar, Provincia de Valparaíso, Región de Valparaíso, Chile
# sin coincidencias ['LAS AZUCENAS', '488', 'EEUU', 'HUECHURABA']  ------  LAS_AZUCENAS 488 EEUU HUECHURABA
# ['TTE', 'MARINA', 'ROLANDO', 'FRODEN', 'BLOCK', 'F', 'DEPTO', '13', 'VILLA', 'ALONSO', 'ARCILLA', 'LA FLORIDA']  ------  TTE MARINA ROLANDO FRODEN BLOCK F DEPTO 13 VILLA ALONSO ARCILLA LA_FLORIDA  -------  Teniente de Marina Rolando Froden, Villa Los Copihues, La Florida, Provincia de Santiago, Región Metropolitana de Santiago, 8240494, Chile
# sin coincidencias ['PJE ISLA', 'QUIRIQUINA', 'CASA', 'ESQUINA', 'QUILPUE']  ------  PJE_ISLA QUIRIQUINA CASA ESQUINA QUILPUE
# sin coincidencias ['CATRICO', 'LANCO']  ------  CATRICO LANCO
# ['INDEPENDENCIA', '1586', 'CASA 2', 'ANTOFAGASTA']  ------  INDEPENDENCIA 1586 CASA_2 ANTOFAGASTA  -------  Independencia, Villa Las Condes, Antofagasta, Provincia de Antofagasta, Región de Antofagasta, 1240000, Chile
# ['BERNARDO', 'OHIGGINS', '2', 'TALTAL']  ------  BERNARDO OHIGGINS 2 TALTAL  -------  Pasaje Bernardo Ohiggins, Villa Patricia Poblete, Curicó, Provincia de Curicó, Región del Maule, 3342121, Chile
# sin coincidencias ['OCHAGAVIA', '0', 'DEPTO', '21', 'EL BOSQUE']  ------  OCHAGAVIA 0 DEPTO 21 EL_BOSQUE
# ['MINERO', 'DELIRIO', 'ALARCON', 'PICARTE', '3', '1445', 'CORONEL', 'BIOBIO', 'LA PENA']  ------  MINERO DELIRIO ALARCON PICARTE 3 1445 CORONEL BIOBIO LA_PENA  -------  Minero Delirio Alarcón Picarte, Villa La Peña 1, Coronel, Provincia de Concepción, Región del Biobío, 4190000, Chile
# sin coincidencias ['CERUSITA', 'LOS MINERALES', 'COPIAPO']  ------  CERUSITA LOS_MINERALES COPIAPO
# ['PASAJE', 'LOS NIRRES', '2028', 'CORONEL', 'BIOBIO', 'POBLACION', 'EDUARDO', 'FREI']  ------  PASAJE LOS_NIRRES 2028 CORONEL BIOBIO POBLACION EDUARDO FREI  -------  Los Ñirres, Población Eduardo Frei, Chillán Viejo, Provincia de Diguillín, Región de Ñuble, 3820000, Chile
# ['STA', 'ISABEL', 'HUNGRIA', 'VILLA', 'ALVEAR', 'LA PINTANA']  ------  STA ISABEL HUNGRIA VILLA ALVEAR LA_PINTANA  -------  Santa Isabel de Hungría, Villa La Paz, La Pintana, Provincia de Santiago, Región Metropolitana de Santiago, 8010000, Chile
# ['LIBERTAD', 'ANCUD', 'LOS LAGOS', 'POBLACION', 'CENTRO']  ------  LIBERTAD ANCUD LOS_LAGOS POBLACION CENTRO  -------  Goleta Ancud, Altos de Chiloé, Castro, Provincia de Chiloé, Región de Los Lagos, 5700196, Chile
# ['PATRICIO', 'LYNCH', 'C', '54', 'VALDIVIA']  ------  PATRICIO LYNCH C 54 VALDIVIA  -------  Avenida Lynch, Inés de Suárez, Las Ánimas, Villa California, Valdivia, Provincia de Valdivia, Región de Los Ríos, 5090262, Chile
# ['SIN', 'CALLE', 'PUERTO', 'VARAS', 'LOS LAGOS', 'LOTEO', 'SANTA', 'ELENA', 'PARCELA', '14', 'RUTA', '143']  ------  SIN CALLE PUERTO VARAS LOS_LAGOS LOTEO SANTA ELENA PARCELA 14 RUTA 143  -------  Ancón sin Salida, Loteo Rubén Darío, Natales, Provincia de Última Esperanza, Región de Magallanes y de la Antártica Chilena, 6160534, Chile
# ['CURICO', 'DON', 'MATIAS', 'PASAJE RAMON', 'FREIRE', '#52']  ------  CURICO DON MATIAS PASAJE_RAMON FREIRE #52  -------  Avenida Arturo Prat, Parque Los Guindos, Sarmiento, Curicó, Provincia de Curicó, Región del Maule, 3345390, Chile
# ['FROILAN', 'LAGOS', 'SEPULVEDA', 'DPTO', '307', 'EDIFICIO', 'TRES', 'LA FLORIDA']  ------  FROILAN LAGOS SEPULVEDA DPTO 307 EDIFICIO TRES LA_FLORIDA  -------  Froilán Lagos Sepúlveda, Lago Lanalhue, La Florida, Provincia de Santiago, Región Metropolitana de Santiago, 8240494, Chile
# ['2', 'NTE', 'BARRIO', 'ESTACION', 'VILLA', 'LOS LIBERTADORES', 'PASAJE TREINTA', 'AGOSTO', '#315', 'CAUQUENES']  ------  2 NTE BARRIO ESTACION VILLA LOS_LIBERTADORES PASAJE_TREINTA AGOSTO #315 CAUQUENES  -------  Estación, Villa Los Volcanes, Frutillar Alto, Frutillar, Provincia de Llanquihue, Región de Los Lagos, 5620166, Chile
# ['SAN MANUEL', '10669', 'JUAN', 'BAUTISTA', 'LA PINTANA']  ------  SAN_MANUEL 10669 JUAN BAUTISTA LA_PINTANA  -------  10669, San Juan Bautista, Villa San Francisco IV, La Pintana, Provincia de Santiago, Región Metropolitana de Santiago, 8010000, Chile
# sin coincidencias ['TOSCANA', '2031', 'CASA', 'TEMUCO']  ------  TOSCANA 2031 CASA TEMUCO
# ['DR', 'CARLOS', 'VILDOSOLA', 'LA ARAUCARIA', 'BLOCK', '#928', 'DEPTO', '106', 'VILLA', 'SANTA', 'BARBARA', 'CASABLANCA']  ------  DR CARLOS VILDOSOLA LA_ARAUCARIA BLOCK #928 DEPTO 106 VILLA SANTA BARBARA CASABLANCA  -------  Carlos Silva Vildósola, Población Santa Cristina, El Bosque, Provincia de Santiago, Región Metropolitana de Santiago, 8012117, Chile
# sin coincidencias ['BALMACEDA', '1419', 'CHAÑARAL']  ------  BALMACEDA 1419 CHAÑARAL
# ['MANUEL', 'RODRIGUEZ', 'VILLA', 'TAMARUGOS', 'POZO', 'ALMONTE']  ------  MANUEL RODRIGUEZ VILLA TAMARUGOS POZO ALMONTE  -------  Manuel Alfaro, Villa Iquique, Santa Emilia Sur, La Tirana, Pozo Almonte, Provincia del Tamarugal, Región de Tarapacá, Chile
# ['CALLE', 'CATALUÑA', 'CASA 30', 'VILLA', 'ESPAÑA', 'HUEPIL', 'TUCAPEL']  ------  CALLE CATALUÑA CASA_30 VILLA ESPAÑA HUEPIL TUCAPEL  -------  Cataluña, Huépil, Tucapel, Provincia de Bío-Bío, Región del Biobío, 4480000, Chile
# ['DR', 'GUILLERMO', 'MUCKE', 'CASA', 'ROJA', 'ALGARROBO']  ------  DR GUILLERMO MUCKE CASA ROJA ALGARROBO  -------  Avenida Doctor Guillermo Mucke, Ignacio Carrera Pinto, El Canelo, Algarrobo, Provincia de San Antonio, Región de Valparaíso, 2711703, Chile
# sin coincidencias ['SAN PEDRO']  ------  SAN_PEDRO
# ['IRENE', 'FREI', 'MZ', 'H10', 'VILLA', 'ALEMANA']  ------  IRENE FREI MZ H10 VILLA ALEMANA  -------  Irene Frei, Villa Caviale, Villa Alemana, Provincia de Marga Marga, Región de Valparaíso, 2450934, Chile
# sin coincidencias ['C', 'ALTO', 'LAGUNA', 'CASA 61', '29', 'VALPARAISO']  ------  C ALTO LAGUNA CASA_61 29 VALPARAISO
# ['RIO', 'CAUCA', 'PASAJE 2027', 'SECTOR', 'PALLIHUE', 'VILLA', 'LOS RIOS', 'ANGELES']  ------  RIO CAUCA PASAJE_2027 SECTOR PALLIHUE VILLA LOS_RIOS ANGELES  -------  Río Cauca, Villa Los Ríos, Paillihue, Los Ángeles, Provincia de Bío-Bío, Región del Biobío, 4440000, Chile
# ['LOS GUINDALES', '111', 'BARRIO', 'ESPERANZA', 'TRANSITORIO', '4', 'CALAMA']  ------  LOS_GUINDALES 111 BARRIO ESPERANZA TRANSITORIO 4 CALAMA  -------  Espacio de Memoria y Resignificación Ex Medialuna de Maipú Centro Transitorio de Detención y Tortura, Plaza Los Toros, Barrio Maipú Centro, Maipú, Provincia de Santiago, Región Metropolitana de Santiago, 9251602, Chile
# ['RIO', 'JANEIRO', '2246', 'ENTRE', 'JUAN', 'ANTONIO', 'RIOS', 'CALAMA']  ------  RIO JANEIRO 2246 ENTRE JUAN ANTONIO RIOS CALAMA  -------  Río de Janeiro, Calama, Provincia de El Loa, Región de Antofagasta, 1395584, Chile
# ['PASAJE NEHUEN', '53', 'REÑACA', 'ALTO', 'VIÑA', 'DEL', 'MAR']  ------  PASAJE_NEHUEN 53 REÑACA ALTO VIÑA DEL MAR  -------  Reñaca Alto, Viña del Mar, Provincia de Valparaíso, Región de Valparaíso, 2520000, Chile
# sin coincidencias ['REPUBICA', '837', 'STA', 'ROSA', 'TEMUCO']  ------  REPUBICA 837 STA ROSA TEMUCO
# ['CONDOMINIO', 'LAS', 'CAMPIÑAS', 'PARCELA', '87', 'COLINA']  ------  CONDOMINIO LAS CAMPIÑAS PARCELA 87 COLINA  -------  Teru Sushi Chile, Las Cabañas, Barrio Portezuelo, San Miguel, Colina, Provincia de Chacabuco, Región Metropolitana de Santiago, 9361382, Chile
# ['SIN', 'CALLE', 'CHILLAN', 'NUBLE', 'BAJO', 'LOS AMIGOS', 'KILOMETRO', '6', 'CAMINO', 'BUSTAMANTE']  ------  SIN CALLE CHILLAN NUBLE BAJO LOS_AMIGOS KILOMETRO 6 CAMINO BUSTAMANTE  -------  Avenida Alonso de Ercilla, Nueva Río Viejo, Chillán, Provincia de Diguillín, Región de Ñuble, 3800720, Chile
# ['SOL', 'NACIENTE', '5', 'REÑACA', 'ALTO', 'VIÑA', 'DEL', 'MAR']  ------  SOL NACIENTE 5 REÑACA ALTO VIÑA DEL MAR  -------  Sol Naciente, Villa Oriente, Reñaca Alto, Viña del Mar, Provincia de Valparaíso, Región de Valparaíso, 2520000, Chile
# ['CAM', 'A', 'VICHICULEN', 'SEGUNDO', 'CALLEJON', 'MANO', 'IZQUIERDA', 'LLAILLAY']  ------  CAM A VICHICULEN SEGUNDO CALLEJON MANO IZQUIERDA LLAILLAY  -------  Vichiculén, El Roble - Las Mazas, Llay-Llay, Provincia de San Felipe de Aconcagua, Región de Valparaíso, 2210000, Chile
# sin coincidencias ['SIN', 'CALLE', 'RANQUIL', 'NUBLE', 'SECTOR', 'CEMENTERIO', 'CAMINO', 'VEGA', 'CONCHA']  ------  SIN CALLE RANQUIL NUBLE SECTOR CEMENTERIO CAMINO VEGA CONCHA
# sin coincidencias ['BERNARDO', 'OHIGGINS', '779', '#779', 'PERALILLO']  ------  BERNARDO OHIGGINS 779 #779 PERALILLO
# ['CANELA', '327', 'CASA', 'ESQUINA', 'PEÑAFLOR']  ------  CANELA 327 CASA ESQUINA PEÑAFLOR  -------  Avenida Esquina Blanca, Villa Casa de Moneda, Maipú, Provincia de Santiago, Región Metropolitana de Santiago, 9251602, Chile
# ['CANAL', 'SAN DIEGO', 'CASA 2607', 'VILLA', 'LOS CANALES', 'PUENTE', 'ALTO']  ------  CANAL SAN_DIEGO CASA_2607 VILLA LOS_CANALES PUENTE ALTO  -------  Pasaje Canal San Diego, Población Los Canales, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8150513, Chile
# ['C', 'CORDILLERA', 'LOS ANDES', '0452', 'SANTA', 'BARBARA']  ------  C CORDILLERA LOS_ANDES 0452 SANTA BARBARA  -------  Cordillera, Villa Diego Portales, Los Andes, Provincia de Los Andes, Región de Valparaíso, 2100000, Chile
# ['PSJE DEL ARCO', 'IRIS', '29', 'P', 'SAN ISIDRO', 'QUILICURA']  ------  PSJE_DEL_ARCO IRIS 29 P SAN_ISIDRO QUILICURA  -------  29, Del Arco Iris, San Isidro, Quilicura, Provincia de Santiago, Región Metropolitana de Santiago, 8700000, Chile
# ['CARDENAL', 'JOSE', 'MARIA', 'CARO', 'BLOCK', '431', 'DPTO', '12', 'SAN FELIPE']  ------  CARDENAL JOSE MARIA CARO BLOCK 431 DPTO 12 SAN_FELIPE  -------  Cardenal José María Caro, Condominio Valle La Cantera, La Cantera, Coquimbo, Provincia de Elqui, Región de Coquimbo, 1790437, Chile
# ['RUTA', 'E46', 'KM', '1', 'LOTE', 'T', 'PARCELA', '12', 'CONCON']  ------  RUTA E46 KM 1 LOTE T PARCELA 12 CONCON  -------  Ruta 1, Taltal, Provincia de Antofagasta, Región de Antofagasta, Chile
# ['YACIMIENTO', 'MINERAL', '427', 'CORONEL', 'BIOBIO', 'POBLACION', 'GENDARME', 'ELIAS', 'AGUILERA']  ------  YACIMIENTO MINERAL 427 CORONEL BIOBIO POBLACION GENDARME ELIAS AGUILERA  -------  427, Yacimiento Mineral El Indio, Población Libertad, Coronel, Provincia de Concepción, Región del Biobío, 4190000, Chile
# ['ALBERTO', 'HOLMGREN', 'ANDERSON', 'CASA', '#310', 'COQUIMBO']  ------  ALBERTO HOLMGREN ANDERSON CASA #310 COQUIMBO  -------  Alberto Holmgren Anderson, Alto Las Pircas, Punta Mira, Coquimbo, Provincia de Elqui, Región de Coquimbo, 1790437, Chile
# ['CAMINO', 'A', 'HUISCAPI', 'LONCOCHE', 'LA ARAUCANIA', 'VILLA', 'CASAHUE', 'LT', '14-2']  ------  CAMINO A HUISCAPI LONCOCHE LA_ARAUCANIA VILLA CASAHUE LT 14-2  -------  Camino Huiscapi, Huiscapi, Loncoche, Provincia de Cautín, Región de la Araucanía, Chile
# sin coincidencias ['ERCILLA', 'CASA', 'QUILLECO']  ------  ERCILLA CASA QUILLECO
# ['ABRANQUIL', '01532', 'POB', 'YERBAS', 'BUENAS', 'LINARES']  ------  ABRANQUIL 01532 POB YERBAS BUENAS LINARES  -------  Abránquil, Yerbas Buenas, Provincia de Linares, Región del Maule, Chile
# sin coincidencias ['EL QUELMEN', 'TENO', 'MAULE', 'SITIO', '10']  ------  EL_QUELMEN TENO MAULE SITIO 10
# ['PASAJE DIECINUEVE', 'Y', 'MEDIO', 'NORTE', 'B 3043', 'SAN CLEMENTE', 'MAULE', 'VILLA', 'BICENTENARIO']  ------  PASAJE_DIECINUEVE Y MEDIO NORTE B_3043 SAN_CLEMENTE MAULE VILLA BICENTENARIO  -------  Minuto y Medio, Ruta J-743, Villa Bicentenario, La Serena, Buena Unión, Molina, Provincia de Curicó, Región del Maule, Chile
# ['CALLE', 'A', '132', 'DONIHUE', 'OHIGGINS', 'VILLA', 'ISMENAR', 'LO', 'MIRANDA', 'DOÑIHUE']  ------  CALLE A 132 DONIHUE OHIGGINS VILLA ISMENAR LO MIRANDA DOÑIHUE  -------  Calle A, Villa Ilusión, Lo Miranda, Doñihue, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, Chile
# ['BRASIL', '633', 'VILLA', 'CAMPOS', 'DEPORTE', 'ROMERAL']  ------  BRASIL 633 VILLA CAMPOS DEPORTE ROMERAL  -------  Chile, Ibicuitinga, Região Geográfica Imediata de Quixadá, Região Geográfica Intermediária de Quixadá, Ceará, Região Nordeste, Brasil
# ['GRAN', 'VIA', '32', 'SALAMANCA', 'TRANQUILLA', 'SECTOR', 'RURAL']  ------  GRAN VIA 32 SALAMANCA TRANQUILLA SECTOR RURAL  -------  Gran Vía, Tranquilla, Salamanca, Provincia de Choapa, Región de Coquimbo, Chile
# ['CAMINO', 'A', 'LOS LAGOS', '120007503', 'HUELLELHUE', 'VALDIVIA']  ------  CAMINO A LOS_LAGOS 120007503 HUELLELHUE VALDIVIA  -------  Ruta 204, Población Ferroviaria, Huellelhue, Valdivia, Provincia de Valdivia, Región de Los Ríos, Chile
# ['MAFIL', 'VILLA', 'LOS', 'CASTAÑOS', 'PSJE', 'OSCAR', 'QUIROZ', 'JARA', '110', 'VALDIVIA']  ------  MAFIL VILLA LOS CASTAÑOS PSJE OSCAR QUIROZ JARA 110 VALDIVIA  -------  Ruta T-335, Villa Los Castaños, Máfil, Provincia de Valdivia, Región de Los Ríos, Chile
# ['CAM', 'INTERNACIONAL', 'QUETROLEUFU', 'KM', '12', 'PUCON']  ------  CAM INTERNACIONAL QUETROLEUFU KM 12 PUCON  -------  Quetroleufu, Pucón, Provincia de Cautín, Región de la Araucanía, Chile
# ...
# ['ERRAZURIZ', '2766', 'DPTO', '12', 'IQUIQUE']  ------  ERRAZURIZ 2766 DPTO 12 IQUIQUE  -------  Errazuriz, Población Araucaria, Cabildo, Provincia de Petorca, Región de Valparaíso, Chile
# ['CIRCUNV', '1761', 'BLOCK', '822', 'DPTO', '302', 'MELIPILLA']  ------  CIRCUNV 1761 BLOCK 822 DPTO 302 MELIPILLA  -------  Camarico, Lo Encañado, San Pedro, Provincia de Melipilla, Región Metropolitana de Santiago, Chile
# ['CHALLAY', 'ALTO', 'PP', '85707', 'ST', '15', 'PAINE', 'BUIN']  ------  CHALLAY ALTO PP 85707 ST 15 PAINE BUIN  -------  Challay Alto, El Escorial, Paine, Provincia de Maipo, Región Metropolitana de Santiago, Chile
# ['BOLDO', '2906', 'CANELO', 'NOS', 'SAN BERNARDO']  ------  BOLDO 2906 CANELO NOS SAN_BERNARDO  -------  Nos, San Bernardo, Provincia de Maipo, Región Metropolitana de Santiago, 8080782, Chile
# ['PJE UNO', '1467', 'CASA', 'CALLE', 'DE']  ------  PJE_UNO 1467 CASA CALLE DE  -------  Plaza de la República de Chile, Casa de Campo, Moncloa-Aravaca, Madrid, Comunidad de Madrid, 28008, España
# ['CAMINO', 'LA ARENA', 'VILLA', 'ALEGRE', 'MAULE', 'SUR', 'RTAL-190']  ------  CAMINO LA_ARENA VILLA ALEGRE MAULE SUR RTAL-190  -------  Camino La Arena, La Nueva Unión, La Arena, Villa Alegre, Provincia de Linares, Región del Maule, Chile
# ['MONSEÑOR', 'LECAROS', 'CASA', 'AMARRILLA', 'AUTO', 'CHOCADO', 'EN', 'EL PATIO', 'COLTAUCO']  ------  MONSEÑOR LECAROS CASA AMARRILLA AUTO CHOCADO EN EL_PATIO COLTAUCO  -------  Instituto Monseñor Lecaros, 383, Arturo Prat, Coltauco, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, Chile
# ['VOLCAN', 'MIÑO', 'ENTRE', 'MEXICO', 'Y', 'ARGENTINA', 'LA SERENA']  ------  VOLCAN MIÑO ENTRE MEXICO Y ARGENTINA LA_SERENA  -------  Volcán Miño, Santa Marta, Talcahuano, Provincia de Concepción, Región del Biobío, 4300329, Chile
# ['PEDRO', 'LUNA', 'BLOK14', 'DEPTO', '104', 'CONCEPCION']  ------  PEDRO LUNA BLOK14 DEPTO 104 CONCEPCION  -------  Pedro Luna, Lo Méndez, Concepción, Provincia de Concepción, Región del Biobío, 4061735, Chile
# ['LAS ACACIAS', 'BOSQUE', 'SANTA', 'CECILIA', 'MELIPILLA']  ------  LAS_ACACIAS BOSQUE SANTA CECILIA MELIPILLA  -------  Las Acacias, Población 11 de Septiembre, San Carlos, Provincia de Punilla, Región de Ñuble, 3841660, Chile
# ['BAQUEDANO', '744', 'LLANQUIHUE', 'LOS LAGOS', '500', 'MTS', 'AL', 'NORTE', 'ESCUELA', 'INES', 'GALLARDO', 'ALVARADO']  ------  BAQUEDANO 744 LLANQUIHUE LOS_LAGOS 500 MTS AL NORTE ESCUELA INES GALLARDO ALVARADO  -------  Baquedano, Población Nestlé, Villa Federico Werner, Llanquihue, Provincia de Llanquihue, Región de Los Lagos, 5610000, Chile
# ['PEDEHUE', 'SAN FERNANDO', 'OHIGGINS', 'ST', '26', 'LT', '1B', 'PLACILLA']  ------  PEDEHUE SAN_FERNANDO OHIGGINS ST 26 LT 1B PLACILLA  -------  Parronales de Pedehue, Las Rosas de Antivero, San Fernando, Provincia de Colchagua, Región del Libertador General Bernardo O'Higgins, Chile
# ['FRANCISCO', 'MONTESSI', 'LAS', 'VIÑAS', 'QUILPUE']  ------  FRANCISCO MONTESSI LAS VIÑAS QUILPUE  -------  Alcalde Francisco Montessi, Las Viñas, Quilpué, Provincia de Marga Marga, Región de Valparaíso, 2430590, Chile
# ['ACONCAGUA', '1644', 'TIERRAS', 'BLANCAS', 'COQUIMBO']  ------  ACONCAGUA 1644 TIERRAS BLANCAS COQUIMBO  -------  Aconcagua, Lomas de San Ramón, Tierras Blancas, Coquimbo, Provincia de Elqui, Región de Coquimbo, 1721411, Chile
# ['PARAGUAY', '1818', 'CASA', 'SAN RAMON']  ------  PARAGUAY 1818 CASA SAN_RAMON  -------  Paraguay, Barrio San Ramón, San Ramón, Provincia de Santiago, Región Metropolitana de Santiago, 8870068, Chile
# ['JUAN', 'LUIS', 'SANFUENTES', '1163', 'CARAHUE']  ------  JUAN LUIS SANFUENTES 1163 CARAHUE  -------  Juan Luis Sanfuentes, Villa Esperanza Alto, Copiapó, Provincia de Copiapó, Región de Atacama, 1532480, Chile
# ['CUATRO', 'MARZO', 'VILLARRICA', 'LA ARAUCANIA', 'NANCUL']  ------  CUATRO MARZO VILLARRICA LA_ARAUCANIA NANCUL  -------  4 de Marzo, Ñancul, Villarrica, Provincia de Cautín, Región de la Araucanía, Chile
# sin coincidencias ['OHIGGINS', 'CASA', 'ESQUINA', 'CELESTE']  ------  OHIGGINS CASA ESQUINA CELESTE
# sin coincidencias ['COMERCIO', 'CARNICERIA', 'COMBARBALA']  ------  COMERCIO CARNICERIA COMBARBALA
# ['MARTE', '12471', 'BERNARDINO', 'PARADA', 'LA PINTANA']  ------  MARTE 12471 BERNARDINO PARADA LA_PINTANA  -------  Bernardino Parada, Peta Miguel Hernández, La Pintana, Provincia de Santiago, Región Metropolitana de Santiago, 8010000, Chile
# ['CALLEJON', 'EL ALAMO', '0', 'LA LINEA', 'TRAS', 'OLLITA', 'PERUANA', 'ALHUE']  ------  CALLEJON EL_ALAMO 0 LA_LINEA TRAS OLLITA PERUANA ALHUE  -------  Callejón El Álamo, Villa El Álamo, San Fernando, Provincia de Colchagua, Región del Libertador General Bernardo O'Higgins, 3071379, Chile
# ['EMILIANA', 'SUBERCASEAUX', 'CASA 109', 'VILLA', 'SAN RAMON', 'PIRQUE']  ------  EMILIANA SUBERCASEAUX CASA_109 VILLA SAN_RAMON PIRQUE  -------  Emiliana Subercaseaux, Villa San Ramón, Pirque, Provincia de Cordillera, Región Metropolitana de Santiago, 9480000, Chile
# ['ALBERTO', 'VALENZUELA', 'LLANOS', '11', '0768', 'PUENTE', 'ALTO']  ------  ALBERTO VALENZUELA LLANOS 11 0768 PUENTE ALTO  -------  Alberto Valenzuela Llanos, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8301703, Chile
# ['PJ', 'CERRO', 'JUNCALITO', '01556', 'P', 'CERRITO', 'ARRIBA', 'PUENTE', 'ALTO', 'VILLA']  ------  PJ CERRO JUNCALITO 01556 P CERRITO ARRIBA PUENTE ALTO VILLA  -------  Carabineros de Chile, Villa Sargento Menadier, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8181117, Chile
# ['V', 'LAS ROSAS', 'PELUCA', 'ANTUCO', 'TUCAPEL']  ------  V LAS_ROSAS PELUCA ANTUCO TUCAPEL  -------  Villa Peluca, Antuco, Provincia de Bío-Bío, Región del Biobío, Chile
# ['W-591', 'CRUCE', 'QUINCHED', '3KM', 'INTERIOR', 'CHONCHI']  ------  W-591 CRUCE QUINCHED 3KM INTERIOR CHONCHI  -------  Ruta W-625, Quinched, Chonchi, Provincia de Chiloé, Región de Los Lagos, Chile
# ['JOSE', 'LEYAN', 'RIVERA DEL RIO', 'SECTOR 4', 'CALLE', 'SALOMON', 'TALAGANTE']  ------  JOSE LEYAN RIVERA_DEL_RIO SECTOR_4 CALLE SALOMON TALAGANTE  -------  José Leyan, Villa Tocornal, Talagante, Provincia de Talagante, Región Metropolitana de Santiago, 9670000, Chile
# ['GENERAL', 'SAN MARTIN', 'DETRAS', 'COLEGIO', 'MARCOS', 'GOICOLEA', 'AL', 'COSTADO', 'LA CARRERA', 'JUAN', 'XXLLL', '214', 'COLINA']  ------  GENERAL SAN_MARTIN DETRAS COLEGIO MARCOS GOICOLEA AL COSTADO LA_CARRERA JUAN XXLLL 214 COLINA  -------  General San Martín, Barrio Maipú Centro, Maipú, Provincia de Santiago, Región Metropolitana de Santiago, 9250678, Chile
# ['OBISPO', 'VILLARROEL', '107', 'VALPARAISO', 'CERRO', 'PERDICES']  ------  OBISPO VILLARROEL 107 VALPARAISO CERRO PERDICES  -------  Obispo Villarroel, Cerro Perdices, Playa Ancha, Valparaíso, Provincia de Valparaíso, Región de Valparaíso, 2370541, Chile
# ['PLAZA', 'LOS NARANJOS', '1672', '-E', 'SI', 'NO', 'ESTA', 'SRA', 'CARLA', 'DEJAR', 'PEDIDO', 'CHELY', 'DPTO', 'E', 'SANTIAGO']  ------  PLAZA LOS_NARANJOS 1672 -E SI NO ESTA SRA CARLA DEJAR PEDIDO CHELY DPTO E SANTIAGO  -------  Chile, S.O.E.M.P.A., Plaza Oubiñas, Azul, Partido de Azul, Buenos Aires, 7300, Argentina
# ['CAMPAMENTO', 'GENESIS', '2', 'ENTRE', 'PORTUGAL', 'CON', 'LUIS', 'CRUZ', 'ANTOFAGSTA', 'ANTOFAGASTA']  ------  CAMPAMENTO GENESIS 2 ENTRE PORTUGAL CON LUIS CRUZ ANTOFAGSTA ANTOFAGASTA  -------  Toma Campamento Indigena 2, Calama, Provincia de El Loa, Región de Antofagasta, Chile
# ['MADRID', '60', 'VILLA', 'ESPAÑA', 'RENGO']  ------  MADRID 60 VILLA ESPAÑA RENGO  -------  Madrid, Villa España, Rengo, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, 2940640, Chile
# ['EL MAITEN', 'ALTOS DEL MELIPILLA', 'CASA 11']  ------  EL_MAITEN ALTOS_DEL_MELIPILLA CASA_11  -------  El Maitén, Altos del Maitén, El Maitén, Melipilla, Provincia de Melipilla, Región Metropolitana de Santiago, 9580887, Chile
# ['CHEQUENLEMU', 'CURICO', 'MAULE']  ------  CHEQUENLEMU CURICO MAULE  -------  Ruta J-645, Chenquelemu Oriente, Curicó, Provincia de Curicó, Región del Maule, Chile
# ['PJ', '9', '0671--', '305', '-', 'P', 'SAN FRANCISCO', 'LUIS', 'PJE QUILICURA']  ------  PJ 9 0671-- 305 - P SAN_FRANCISCO LUIS PJE_QUILICURA  -------  Calle Chile, Coloncito, residencial coopeve o las americas 2, Canto del Llano, Distrito de Santiago, Veraguas, 0924, Panamá
# ['SANTA', 'AMELIA', '85', 'PICHIDEGUA', 'OHIGGINS', 'POBLACION', 'EL LADRILLO', 'ENTRE', 'UNA', 'BOTILLERIA', 'LLAMADA', 'GEMITA', 'Y', 'UN', 'CARRO', 'VERCOMIDA', 'RAPIDA']  ------  SANTA AMELIA 85 PICHIDEGUA OHIGGINS POBLACION EL_LADRILLO ENTRE UNA BOTILLERIA LLAMADA GEMITA Y UN CARRO VERCOMIDA RAPIDA  -------  Santa Amelia, Pichidegua, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, Chile
# ['NILCUNLAUTA', '26', 'ANTES DEL MINIMARKET', 'ESTEBAN', 'DONEMPIEZA', 'EL CAMINO', 'TIERRA', 'SAN FERNANDO']  ------  NILCUNLAUTA 26 ANTES_DEL_MINIMARKET ESTEBAN DONEMPIEZA EL_CAMINO TIERRA SAN_FERNANDO  -------  Nilcunlauta, San Fernando, Provincia de Colchagua, Región del Libertador General Bernardo O'Higgins, 3071937, Chile
# ['DIRIGENTE', 'ISRAEL', 'MENDEZ', 'NAVARRO', 'CASA', 'CERRILLOS']  ------  DIRIGENTE ISRAEL MENDEZ NAVARRO CASA CERRILLOS  -------  Dirigente Israel Méndez Navarro, Barrio Portal Oeste, Cerrillos, Provincia de Santiago, Región Metropolitana de Santiago, 9222145, Chile
# ['NAZARET', '277', 'DPTO', '12', 'LA ERMITA', 'LO', 'BARNECHEA']  ------  NAZARET 277 DPTO 12 LA_ERMITA LO BARNECHEA  -------  Nazaret, La Ermita, Lo Barnechea, Provincia de Santiago, Región Metropolitana de Santiago, 7710414, Chile
# ['PARCELA', 'N 5', 'SOTAQUI', 'OVALLE', 'SUBIR', 'ALMACEN', 'VIEJO', 'RAFA', 'A', 'LA DERECHA', 'E', 'IZQUIERDA', 'HASTA', 'EL FINAL']  ------  PARCELA N_5 SOTAQUI OVALLE SUBIR ALMACEN VIEJO RAFA A LA_DERECHA E IZQUIERDA HASTA EL_FINAL  -------  Chile
# ['RIO', 'IMPERIAL', 'BK', '9', 'DEPTO', '31', 'EL OLIVAR', 'SECTOR', 'A', 'PRIMER', 'PARADERO DEL ENTRANDO', 'POR', 'TRONCAL', 'VIÑA', 'MAR']  ------  RIO IMPERIAL BK 9 DEPTO 31 EL_OLIVAR SECTOR A PRIMER PARADERO_DEL_ENTRANDO POR TRONCAL VIÑA MAR  -------  Río Imperial, Viña Oriente, Viña del Mar, Provincia de Valparaíso, Región de Valparaíso, 2562126, Chile
# ['RUTA', 'Q-61', 'PDRO', '14', 'INTERIOR', 'ALTO', 'BIOBIO']  ------  RUTA Q-61 PDRO 14 INTERIOR ALTO BIOBIO  -------  Ruta Q-61, Comunidad Quepuca Interior, Alto Biobío, Provincia de Bío-Bío, Región del Biobío, Chile
# ['SAN JOSE', '353', 'EMBALSE', 'BUCLARO', 'COQUIMBO']  ------  SAN_JOSE 353 EMBALSE BUCLARO COQUIMBO  -------  Embalse Puclaro, Vicuña, Provincia de Elqui, Región de Coquimbo, Chile
# ['VENANCIA', 'LEIVA', 'DP23', 'LA PINTANA']  ------  VENANCIA LEIVA DP23 LA_PINTANA  -------  Venancia Leiva, Villa La Cultura, San Ramón, Provincia de Santiago, Región Metropolitana de Santiago, 8870068, Chile
# ['RIO', 'VOLCAN', 'DPTO', '216', 'VILLA', 'MAMIÑA', '1', 'PUENTE', 'ALTO']  ------  RIO VOLCAN DPTO 216 VILLA MAMIÑA 1 PUENTE ALTO  -------  Río Volcán, Población San Francisco de Asís, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8167426, Chile
# ['PJE HIERBA', 'BUENA', '3408', 'SAN', 'PEDRO DE LA PAZ']  ------  PJE_HIERBA BUENA 3408 SAN PEDRO_DE_LA_PAZ  -------  San Pedro de la Paz, Provincia de Concepción, Región del Biobío, Chile
# ['CONDELL', 'DEPTO', '206', 'PROVIDENCIA']  ------  CONDELL DEPTO 206 PROVIDENCIA  -------  Condell, Barrio Vaticano Chico, Providencia, Provincia de Santiago, Región Metropolitana de Santiago, 7501231, Chile
# ['PUENTE', '21', 'MAYO', 'PASANDO', 'EL', 'BADEN DEL COLEGIO', 'HACIA', 'ABAJO', 'LOS BOMBEROS', 'A', 'MANO', 'IZQUIERDA', 'HAY', 'UN', 'CAYEJON', 'CASA', 'ROJA', 'SAN FELIPE']  ------  PUENTE 21 MAYO PASANDO EL BADEN_DEL_COLEGIO HACIA ABAJO LOS_BOMBEROS A MANO IZQUIERDA HAY UN CAYEJON CASA ROJA SAN_FELIPE  -------  Puente Peatonal 21 de Mayo, Vega Monumental, Concepción, Provincia de Concepción, Región del Biobío, 4061735, Chile
# ['ARGENTINA', '442', 'ENTRE', 'CALLE', 'PERU', 'Y', 'ARTURO', 'PRAT', 'BUIN']  ------  ARGENTINA 442 ENTRE CALLE PERU Y ARTURO PRAT BUIN  -------  Avenida Vicente Méndez, Villa Portal Quilamapu, Chillán, Provincia de Diguillín, Región de Ñuble, 3800381, Chile
# ['STA', 'ELENA', 'HUECHURABA', 'DEPTO', '503']  ------  STA ELENA HUECHURABA DEPTO 503  -------  Condominio Santa María de Huechuraba, Huechuraba, Provincia de Santiago, Región Metropolitana de Santiago, Chile
# ['ESPERANZA', 'SAGRADA', 'FAMILIA', 'MAULE', 'DETRAS', 'BOMBA', 'BENCINA']  ------  ESPERANZA SAGRADA FAMILIA MAULE DETRAS BOMBA BENCINA  -------  Esperanza, Pudahuel, Villa Prat, Sagrada Familia, Provincia de Curicó, Región del Maule, Chile
# ['MAR', 'CHILE', 'CASA', 'CERRO', 'NAVIA']  ------  MAR CHILE CASA CERRO NAVIA  -------  Las Fragatas / Mar de Chile, Mares de Chile, Poblacion Alianza, Cerro Navia, Provincia de Santiago, Región Metropolitana de Santiago, 9090184, Chile
# ['AVDA', 'EL HUIQUE', 'PALMILLA', 'OHIGGINS', 'SIGUES', 'Y', 'LLEGAS', 'AL', 'COLEGIO', 'LOS OLMOS', 'HACIA', 'DENTRO', 'HAY', 'UN', 'FUNDO', 'A', 'LA PENULTIMA', 'CASA']  ------  AVDA EL_HUIQUE PALMILLA OHIGGINS SIGUES Y LLEGAS AL COLEGIO LOS_OLMOS HACIA DENTRO HAY UN FUNDO A LA_PENULTIMA CASA  -------  Avenida El Huique, El Millán Pupilla, San José del Carmen, Palmilla, Provincia de Colchagua, Región del Libertador General Bernardo O'Higgins, Chile
# ['SAN PEDRO', '182', 'VILLA', 'ALBERTO', 'HURTADO', 'PADRE']  ------  SAN_PEDRO 182 VILLA ALBERTO HURTADO PADRE  -------  San Pedro, Villa Los Libertadores, Frutillar Alto, Frutillar, Provincia de Llanquihue, Región de Los Lagos, 5620106, Chile
# ['CURQUE', 'ALTO', 'CAMINO', 'AL', 'OBSERVATORIO', 'MANGANESO', 'TERRENO', 'GRANVARIAS', 'CASAS', 'LA PRIMERA', 'QUE', 'SE', 'VE', 'ES', 'UNA', 'ROJA', 'Y', 'UN', 'CONTAINER', 'GRIS', 'ANDACOLLO']  ------  CURQUE ALTO CAMINO AL OBSERVATORIO MANGANESO TERRENO GRANVARIAS CASAS LA_PRIMERA QUE SE VE ES UNA ROJA Y UN CONTAINER GRIS ANDACOLLO  -------  Antiguo Camino al Aeródromo, Chepiquilla, Andacollo, Provincia de Elqui, Región de Coquimbo, Chile
# ['PDTE', 'JUAN', 'LUIS', 'SANFUENTES', 'SITIO', '13', 'VILLA', 'MAPUCHE', 'POZO', 'ALMONTE']  ------  PDTE JUAN LUIS SANFUENTES SITIO 13 VILLA MAPUCHE POZO ALMONTE  -------  Juan Luis Sanfuentes, Villa Esperanza Alto, Copiapó, Provincia de Copiapó, Región de Atacama, 1532480, Chile
# ['PASAJE SAN', 'ENRIQUE', '3000', 'CASA 95', 'PUENTE', 'ALTO']  ------  PASAJE_SAN ENRIQUE 3000 CASA_95 PUENTE ALTO  -------  Pasaje San Enrique, Parque San Francisco, Puente Alto, Provincia de Cordillera, Región Metropolitana de Santiago, 8207897, Chile
# ['PJE DOS', 'CASA', 'PUENTE', 'ALTO']  ------  PJE_DOS CASA PUENTE ALTO  -------  Estero Puente Alto o Casa de Piedra, Carahue, Provincia de Cautín, Región de la Araucanía, Chile
# ['BAQUEDANO', 'CASA 138', 'SAN BERNARDO']  ------  BAQUEDANO CASA_138 SAN_BERNARDO  -------  Baquedano, Población Obrero Ferroviaria, San Bernardo, Provincia de Maipo, Región Metropolitana de Santiago, 8080782, Chile
# ['SAN JAVIER', '2646', 'MAULE', 'CERRO', 'LA CRUZ']  ------  SAN_JAVIER 2646 MAULE CERRO LA_CRUZ  -------  Casa De Retiro San Francisco Javier, Crescente Errázuriz, Barrio Javiera Carrera, Ñuñoa, Provincia de Santiago, Región Metropolitana de Santiago, 7750490, Chile
# ['LOS NARANJOS', '12466', 'CASA', 'PORTON', 'MADERA', 'EL BOSQUE']  ------  LOS_NARANJOS 12466 CASA PORTON MADERA EL_BOSQUE  -------  Los Naranjos, Villa Madera, El Rosal, Coelemu, Provincia de Itata, Región de Ñuble, 3970000, Chile
# ['DIEGO', 'PORTALES', '823']  ------  DIEGO PORTALES 823  -------  823, Avenida Diego Portales, Villa Las Asturias, La Florida, Provincia de Santiago, Región Metropolitana de Santiago, 8301711, Chile
# ['LONQUEN', 'SUR', 'PARADERO', '37', '12', 'SITIO', '39', 'TALAGANTE']  ------  LONQUEN SUR PARADERO 37 12 SITIO 39 TALAGANTE  -------  Lonquén Sur, Calera de Tango, Provincia de Maipo, Región Metropolitana de Santiago, Chile
# ['MEXICO', 'B13', 'ANTOFAGASTA']  ------  MEXICO B13 ANTOFAGASTA  -------  México, Antofagasta, Provincia de Antofagasta, Región de Antofagasta, 1240000, Chile

# %%
import pandas as pd
res = pd.concat(arr_df_tmp)

ret = pd.merge(df_tmp, res, on="DIRECCION DE DOMICILIO", how="left")

# %%
print("A")
# Out:
# A

# %%
ret.to_csv('./data/out/ad2.csv')
