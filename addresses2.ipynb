# %%
from validate_adrresses import validate_address
import pandas as pd
import os
from tqdm import tqdm
print(os.getcwd())
# Out:
# c:\Users\lagg1\Documents\Belcorp\iteration_adresses

# %%
df = pd.read_csv('./data/direcciones.csv', sep=';')
# Out:
# C:\Users\lagg1\AppData\Local\Temp\ipykernel_36124\4095483860.py:1: DtypeWarning: Columns (4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/direcciones.csv', sep=';')

# %%
cols = [col for col in df]
col1 = cols[:3]
col2 = cols[3:]

cols = []
for col in col1:
    cols.append(col)
cols.append("NUEVA DIRECCION")
for col in col2:
    cols.append(col)

# %%
df["NUEVA DIRECCION"] = None
df = df.reindex(columns=cols)
df = df[df["IND TERRITORIOS"] == 9]

# %%
df_tmp = df[["DIRECCION DE DOMICILIO", "COMUNA DOMICILIO", "NUEVA DIRECCION", "X", "Y"]]
df_tmp

# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np

ddata = dd.from_pandas(df_tmp, npartitions=30)

# Sample meta dataframe to indicate the structure of the output
meta = pd.DataFrame({
    "DIRECCION DE DOMICILIO": pd.Series(dtype='str'),
    "COMUNA DOMICILIO": pd.Series(dtype='str'),
    "NUEVA DIRECCION": pd.Series(dtype='str'),
    "X": pd.Series(dtype='float'),
    "Y": pd.Series(dtype='float')
})

def apply_validate_address(df_chunk):
    # Handle missing values before passing to validate_address
    df_chunk[["DIRECCION DE DOMICILIO", "COMUNA DOMICILIO"]] = df_chunk[["DIRECCION DE DOMICILIO", "COMUNA DOMICILIO"]].fillna("")
    
    # Apply the validation function to each row and unpack the results
    df_chunk[["NUEVA DIRECCION", "X", "Y"]] = df_chunk.apply(
        lambda row: pd.Series(validate_address(row["DIRECCION DE DOMICILIO"] + " " + row["COMUNA DOMICILIO"])),
        axis=1
    )
    return df_chunk

# Map the function to each partition, with the meta keyword to define the structure
res = ddata.map_partitions(apply_validate_address, meta=meta).compute()
# Out:
# sin coincidencias ['PJE RIGEL', 'N 2792', 'B 202']  ------  PJE RIGEL N 2792 B 202 CERCA NEGOCIO ROSADO LLAMADO PERLA PIRQUE
# sin coincidencias ['VALLE DEL ACONCAGUA', 'CASA 590', 'LAMPA']  ------  VALLE DEL ACONCAGUA CASA 590 LAMPA
# ['PASAJE TRES', '4413', 'PEDRO', 'AGUIRRE', 'CERDA', 'METROPOLITANA']  ------  PASAJE TRES 4413.PEDRO AGUIRRE CERDA.METROPOLITANA. REFERENCIA TIKAL SAN MIGUEL  -------  Pasaje Tres, Cardenal Raúl Silva Henriquez, Pedro Aguirre Cerda, Provincia de Santiago, Región Metropolitana de Santiago, 8490153, Chile
# sin coincidencias ['PJE DIEGO', 'PORTALES', 'CASA 911', 'COQUIMBO']  ------  PJE. DIEGO PORTALES CASA 911 COQUIMBO
# sin coincidencias ['LOS LIBERTADORES', 'CASI']  ------  LOS LIBERTADORES CASI FRENTE ARIZTIA EL MONTE
# sin coincidencias ['MOLINA', 'PASAJE 2', 'VILLA', 'LOS GIRASOLES', 'CASA 2046']  ------  MOLINA PASAJE 2 VILLA LOS GIRASOLES CASA 2046 MOLINA
# sin coincidencias ['LOS ALELIES', '1911', 'ALTO', 'HOSPICIO']  ------  LOS ALELIES 1911 1911 ALTO HOSPICIO
# sin coincidencias ['MANUEL', 'BULNES', 'SAN ANTONIO', 'CHILE', 'CERRO LA VIRGEN']  ------  MANUEL BULNES, SAN ANTONIO, CHILE CERRO LA VIRGEN SAN ANTONIO
# ['COMANDANTE', 'FRANCISCO', 'ANCAPI', 'PADRE', 'LAS', 'CASAS']  ------  COMANDANTE FRANCISCO ANCAPI SN PADRE LAS CASAS  -------  Comandante Malbec / Padre Alfredo Arteaga, Comandante Malbec, Pueblito de Lo Barnechea, Lo Barnechea, Provincia de Santiago, Región Metropolitana de Santiago, 7690083, Chile
# ['OBISPO', 'VILLARROEL', '107', 'VALPARAISO', 'CERRO', 'PERDICES']  ------  OBISPO VILLARROEL 107, VALPARAISO, CERRO PERDICES VALPARAISO  -------  Obispo Villarroel, Cerro Perdices, Playa Ancha, Valparaíso, Provincia de Valparaíso, Región de Valparaíso, 2370541, Chile
# sin coincidencias ['CHAQUILVIN', 'POBLACION', 'SAN JOSE', 'DE LA DEHESA', 'LONQUIMAY']  ------  CHAQUILVIN POBLACION SAN JOSE DE LA DEHESA LONQUIMAY
# ['PRINCIPAL', '2', '616451', 'VIÑA', 'DEL', 'MAR', 'CALLE', 'LIMITE', 'LOMA', 'SUR', 'FORESTAL']  ------  AV PRINCIPAL 2 616451, VIÑA DEL MAR AV PRINCIPAL 2 CALLE LIMITE LOMA SUR FORESTAL VIÑA DEL MAR  -------  Principal, Población Lourdes, Nueva Aurora, Viña del Mar, Provincia de Valparaíso, Región de Valparaíso, 2580347, Chile
# sin coincidencias ['LOMAS DEL MIRADOR', '733', 'SANTA', 'JUANA']  ------  LOMAS DEL MIRADOR 733 SANTA JUANA SANTA JUANA
# sin coincidencias ['PASAJE MARIA', 'TERESA', 'MOSTAZAL', 'OHIGGINS', 'CANCHA', 'LOS PICHICO']  ------  PASAJE MARIA TERESA SN.MOSTAZAL.OHIGGINS. CANCHA LOS PICHICO MOSTAZAL
# sin coincidencias ['SECTOR 4', 'VILLA', 'ARRIBA', 'ALHUE', 'CHACABUCO', '']  ------  SECTOR 4 VILLA ARRIBA ALHUE SECTOR CHACABUCO SN ALHUE ALHUE
# sin coincidencias ['PARQUE', 'NAC', 'FRAY', 'JORGE', '1100', 'COQUIMBO LA SERENA']  ------  PARQUE NAC FRAY JORGE 1100 COQUIMBO LA SERENA
# sin coincidencias ['COSTANERA', 'BL', '1420', 'D13', 'SAN FELIPE', 'DEPARTAMENTAL']  ------  COSTANERA BL 1420 D13, SAN FELIPE DEPARTAMENTAL SAN FELIPE
# sin coincidenciassin coincidencias ['EL AGRO', '0', 'LOS CORRALONES', 'NEGRETE']  ------  EL AGRO 0 LOS CORRALONES NEGRETE NEGRETE
#  ['TASOS', '730', 'CASA', 'PUDAHUEL']  ------  TASOS 730 CASA 730 PUDAHUEL
# sin coincidencias ['NUEVA', '125', 'CURICO', 'MAULE', 'CASA', 'ESQUINA']  ------  NUEVA 125.CURICO.MAULE. CASA ESQUINA CURICO
# ['ACEVEDO', 'HERNANDEZ', 'CASA', '#28', 'NUMERO', 'CALLE', '63', 'FORESTAL', 'VIÑA', 'DEL', 'MAR']  ------  ACEVEDO HERNANDEZ CASA #28, NUMERO DE CALLE 63, FORESTAL VIÑA DEL MAR  -------  Acevedo Hernández, Santa Sabina, Concepción, Provincia de Concepción, Región del Biobío, 4061735, Chile
# ['BUSTOS', 'MEDINA', '369', 'SE', '24210', 'SAN CARLOS']  ------  BUSTOS MEDINA 369 SE 24210 SAN CARLOS  -------  Melanio Bustos Medina, Puesta del Sol, San Carlos, Provincia de Punilla, Región de Ñuble, 3841660, Chile
# ['PA', 'LOS PIMIENTOS', '86DOÑA', 'CARMEN', 'SARMIENTO', 'CURICO', 'RAUCO']  ------  PA LOS PIMIENTOS 86DOÑA CARMEN SARMIENTO CURICO RAUCO  -------  Pasaje Los Pimientos, Doña Carmen, Sarmiento, Curicó, Provincia de Curicó, Región del Maule, 3345390, Chile
# ['PACIFICO', '741', '313', 'TORRE', 'PLAYA', 'BLANCA LA HIGUERA']  ------  AV. PACIFICO 741 313, TORRE PLAYA BLANCA LA HIGUERA  -------  Chile, Acandí, Darién, Chocó, RAP Pacífico, Colombia
# ['TRES', 'NORTE', '1999', 'VILLA', 'SANTA', 'CAROLINA', 'MACUL']  ------  TRES NORTE 1999 VILLA SANTA CAROLINA MACUL  -------  Norte, Barrio O'Higgins, San Roque, Valparaíso, Provincia de Valparaíso, Región de Valparaíso, 2390382, Chile
# sin coincidencias ['LAS', 'ARAUCARIAS', 'RENACER', 'PASAJE 4', 'CASA 100', 'LOS MUERMOS']  ------  LAS ARAUCARIAS RENACER PASAJE 4 CASA 100 LOS MUERMOS
# sin coincidencias ['LAS', 'LOMAS', 'POMPEYA', 'SUR', 'QUILPUE']  ------  LAS LOMAS POMPEYA SUR QUILPUE
# sin coincidencias ['VICTOR', 'JARA', 'CASA 511', 'LANCO']  ------  VICTOR JARA CASA 511 LANCO
# ['PJE RO', 'HUAQUI', '1025', 'CORONEL', 'CHILE', 'FRANK', 'MARDONES']  ------  PJE. RO HUAQUI 1025, CORONEL, CHILE FRANK MARDONES CORONEL  -------  Chile, Población Rosita O'Higgins, Chillán, Provincia de Diguillín, Región de Ñuble, 3780000, Chile
# sin coincidencias ['DOS', 'CASA 2081', 'MELIPILLA']  ------  DOS CASA 2081 MELIPILLA
# sin coincidencias ['LOS CANELOS', '187', 'VILLA', 'QUILLAYES', 'ANTUCO']  ------  LOS CANELOS 187 VILLA LOS QUILLAYES ANTUCO
# sin coincidencias ['CAMPAMENTO', 'ISRAEL', 'SECTOR 5', 'CASA 03', 'A', 'COLINA']  ------  CAMPAMENTO ISRAEL SECTOR 5 CASA 03 A CAMPAMENTO ISRAEL COLINA
# ['ESFUERZO', '186', 'N 48', 'ILLAPEL', 'POBLACION', 'RENACER']  ------  ESFUERZO 186 N.48 ILLAPEL POBLACION RENACER, ILLAPEL  -------  Esfuerzo, Comité Fe y Esperanza, Alerce, Puerto Montt, Provincia de Llanquihue, Región de Los Lagos, Chile
# ['25', 'ENERO', '1002', 'RECOLETA', 'ENTRAR', 'POR', 'CALLE', 'SALZBURGO']  ------  25 DE ENERO 1002 RECOLETA ENTRAR POR CALLE SALZBURGO FRENTE A METRO VESP.NORTE RECOLETA  -------  25 de Enero, Barrio Salzburgo, Recoleta, Provincia de Santiago, Región Metropolitana de Santiago, 9362427, Chile
# sin coincidencias ['EL HUIQUE', 'SANTA', 'MATILPALMILLA']  ------  AV. EL HUIQUE SANTA MATILDE SN PALMILLA PALMILLA
# sin coincidencias ['BERNARDO', 'OHIGGINS', '685', 'ANDORRA', 'VALPARAISO']  ------  BERNARDO OHIGGINS 685 ANDORRA VALPARAISO
# sin coincidencias ['MANUEL', 'BULNES', '1073']  ------  MANUEL BULNES 1073 LLAMAR CUANDO ESTE EN EL LUGAR POR QUE HAY VARIAS FAMILIAS QUE VIVEN AHY IQUIQUE
# sin coincidencias ['Hilda', 'madrid', '8043', 'ANTOFAGASTA']  ------  Hilda madrid 8043 ANTOFAGASTA
# sin coincidencias ['COLLAGUE', '565', 'PADRE', 'LAS', 'CASAS']  ------  COLLAGUE 565 PADRE LAS CASAS
# sin coincidencias ['C', 'LAS', 'QUILAS', 'TORRE', 'DPTO', '207', 'TEMUCO']  ------  C. LAS QUILAS TORRE C DPTO 207 TEMUCO
# sin coincidencias ['ARTURO', 'PRAT', 'CASA', 'COIHUECO']  ------  ARTURO PRAT CASA COIHUECO
# sin coincidencias ['C', 'LOS MAQUIS', 'A', '50', 'METROS DEL CEMENTERIO', 'PELEQUEN', 'MALLOA']  ------  C. LOS MAQUIS A 50 METROS DEL CEMENTERIO DE PELEQUEN MALLOA
# ['JOSE', 'ANTONIO', 'ALDUNATE', '2137', 'MELIPILLA', 'CHILE', 'PARQUE', 'JUEGOS', 'VILLA', 'COLONIAL', 'II']  ------  JOSE ANTONIO ALDUNATE 2137, MELIPILLA, CHILE PARQUE DE JUEGOS VILLA COLONIAL II MELIPILLA  -------  Rua Chile, Chácara das Paineiras, Cecap 2, Votuporanga, Região Imediata de Votuporanga, Região Geográfica Intermediária de São José do Rio Preto, São Paulo, Região Sudeste, 15502-095, Brasil
# ['MARIA', 'AGUILERA', 'PARCELA', '138', 'POZO', 'AL', 'MONTE', 'IQUIQUE']  ------  MARIA AGUILERA PARCELA  138 POZO AL MONTE IQUIQUE  -------  Pozo Toyo, Iquique, Provincia de Iquique, Región de Tarapacá, Chile
# sin coincidenciassin coincidencias ['RAHUE', 'CAMINO', 'INTERNACIONAL', 'COPIAPO']  ------  RAHUE CAMINO INTERNACIONAL COPIAPO
#  ['PJE TENRI', '731', 'LA', 'SERENA']  ------  PJE. TENRI 731 LA SERENA
# sin coincidencias ['LAURA', 'GARCIA', 'HUIDOBRO', 'CASA 91', 'RETIRO']  ------  LAURA GARCIA HUIDOBRO CASA 91 RETIRO
# ['NIHUINCO', '1568', 'VILLA', 'LOS ESTEROS', 'MULCHEN']  ------  NIHUINCO 1568 VILLA LOS ESTEROS MULCHEN  -------  Nihuinco, Villa El Sol, La Granja, Mulchén, Provincia de Bío-Bío, Región del Biobío, 0000444, Chile
# sin coincidencias ['CALLEJON', 'LAS', 'PRADERAS', 'CODIGUA', 'A', 'MANO', 'DERECHA']  ------  CALLEJON LAS PRADERAS SN CODIGUA CALLEJON A MANO DERECHA FRENTE AL NEGOCIO VIVI MELIPILLA
# ['TOCORNAL', 'EL LLANO', 'SANTA', 'MARIA']  ------  TOCORNAL EL LLANO . SANTA MARIA  -------  Tocornal, Las Cadenas, El Llano, Santa María, Provincia de San Felipe de Aconcagua, Región de Valparaíso, 2100000, Chile
# sin coincidencias ['OLGA', 'POBLETE', 'VILLA', 'ESPERANZA', 'MULCHEN']  ------  OLGA POBLETE VILLA ESPERANZA MULCHEN
# ['ESPERANZA', '2264', '33', 'BLOCK', '30', 'SAN RAMON']  ------  ESPERANZA 2264 33 BLOCK 30 SAN RAMON SAN RAMON  -------  Chile, El Retiro, Garrido, Ciudad de Camagüey, Camagüey, 70600, Cuba
# ['CAMINO', 'LOS GALPONES', 'PITRUFQUEN LA ARAUCANIA', 'NUMERO', 'DOMICILIO', '1']  ------  CAMINO LOS GALPONES SN.PITRUFQUEN.LA ARAUCANIA. NUMERO DOMICILIO 1 PITRUFQUEN  -------  Camino Pitrufquén - Loica, Gorbea, Provincia de Cautín, Región de la Araucanía, Chile
# ['PAPA', 'DAMASO', 'II', 'VILLA', 'JUAN', 'PABLO', 'LL', 'SAN FELIPE']  ------  PAPA DAMASO II VILLA JUAN PABLO LL SAN FELIPE  -------  Clínica Franz - Odontólogos Universidad de Chile, 695, San Francisco, Población Juan Costa, Puerto Varas, Provincia de Llanquihue, Región de Los Lagos, 5550596, Chile
# ['SAN MARTIN', 'VILLA', 'LOMAS', 'LONCURA', 'CASA 5', 'QUINTERO']  ------  SAN MARTIN VILLA LOMAS DE LONCURA CASA 5 QUINTERO  -------  Villa Lomas de Loncura, Loncura, Quintero, Provincia de Valparaíso, Región de Valparaíso, 8400000, Chile
# sin coincidencias ['SAN PEDRO', 'PRINCIPAL', 'LOICA', 'MARIA', 'PINTO']  ------  SAN PEDRO, PRINCIPAL SN SAN PEDRO LOICA MARIA PINTO
# sin coincidencias ['LOS MONOS', 'SAN CARLOS']  ------  LOS MONOS, SAN CARLOS SAN CARLOS SAN CARLOS
# ['LA', 'VIÑA', '334', 'POR', 'EYZAGUIRRE', 'PUENTE', 'ALTO']  ------  LA VIÑA 334 POR EYZAGUIRRE PUENTE ALTO  -------  La Viña, Cabildo, Provincia de Petorca, Región de Valparaíso, Chile
# ['C', '4', 'DEPTO', '11', 'GLORIAS', 'NAVALES', 'NUEVO', 'HORIZONTE', '1', 'VIÑA', 'DEL', 'MAR']  ------  C. 4 DEPTO 11 GLORIAS NAVALES NUEVO HORIZONTE 1 VIÑA DEL MAR  -------  Viña Mar, Casablanca, Provincia de Valparaíso, Región de Valparaíso, Chile
# sin coincidencias ['MANUEL', 'RODRIGUEZ', 'CASA', 'NUMERO', '1855', 'IQUIQUE']  ------  MANUEL RODRIGUEZ CASA NUMERO 1855 IQUIQUE
# ['DOLORES', '235', 'CASA', 'ROJA']  ------  DOLORES 235 CASA ROJA, FRENTE AL NEGOCIO QUILPUE  -------  Casa Roja, Pasaje Gálvez, Cerro Concepción, Almendral, Valparaíso, Provincia de Valparaíso, Región de Valparaíso, 2340000, Chile
# sin coincidencias ['CUATRO', '5', 'CASA 24', 'MELIPILLA']  ------  CUATRO 5 CASA 24 MELIPILLA
# ['ANGEL', 'CRUCHAGA', 'STA', 'MARIA', '1661', 'VILLA', 'DOMINGO', 'SILVA', 'CURICO']  ------  ANGEL CRUCHAGA STA  MARIA 1661 VILLA DOMINGO  SILVA  CURICO. CURICO. CURICO  -------  Pasaje Angel Cruchaga, Villa Alameda, Curicó, Provincia de Curicó, Región del Maule, 3400001, Chile
# ['SITIO', 'MARIPOSAS', 'CENTRO', 'SAN CLEMENTE', 'ENTRE LA POSTA', 'Y', 'EL RETEN', 'MARIPOSA', 'MAULE']  ------  SITIO SN MARIPOSAS CENTRO SAN CLEMENTE ENTRE LA POSTA Y EL RETEN DE MARIPOSA MAULE  -------  CESFAM San Clemente, Paseo La Concepción, Población Gabriela Mistral, San Clemente, Provincia de Talca, Región del Maule, Chile
# ['CALLE', 'A', '147', 'RENGO', 'OHIGGINS', 'POBLACION', 'LAS', 'TORRES']  ------  CALLE A 147.RENGO.OHIGGINS. POBLACION LAS TORRES RENGO  -------  Aguas Antofagasta - Estanque Ohiggins (3200 m3), Taltal, Provincia de Antofagasta, Región de Antofagasta, Chile
# sin coincidencias ['LAGO', 'MAIHUE', '41', 'LANCO']  ------  LAGO MAIHUE 41.LANCO LANCO LANCO
# sin coincidencias ['BIO', 'PABLO', 'NERUDA', 'PJE 3', 'CASA 18', 'CHIGUAYANTE']  ------  BIO BIO PABLO NERUDA, PJE 3, CASA 18 CHIGUAYANTE
# ['BEDER', 'SALAZAR', 'POR', 'CALLE', 'BALMACEDA', 'AL', 'COSTADO', 'DE LA ESCUELA', 'GRECIA', 'TALAGANTE']  ------  BEDER SALAZAR POR CALLE BALMACEDA, AL COSTADO DE LA ESCUELA GRECIA TALAGANTE  -------  Calle Angosta, Villa Jesus, Olivar Bajo, Olivar, Provincia de Cachapoal, Región del Libertador General Bernardo O'Higgins, Chile
# ['LAS', 'BRISAS', '5', 'COMUNIDAD', 'PARCELA', '1', 'ELTABO', 'VILLA', 'EL TABO', 'SAN ANTONIO']  ------  LAS BRISAS 5 COMUNIDAD PARCELA 1 ELTABO VILLA EL TABO SAN ANTONIO  -------  Las Brisas, Comunidad Huallilemu, Isla Negra, Punta de Tralca, El Quisco, Provincia de San Antonio, Región de Valparaíso, Chile
# ['CAMPAMENTO', 'FLOR DEL NORTE', 'CASA 62', 'POR', 'EL ROBLE', '1396', 'ALMACEN', 'CON', 'CIRCUNVALACIN', 'ANTOFAGASTA']  ------  CAMPAMENTO FLOR DEL NORTE CASA 62 POR EL ROBLE 1396 ALMACEN CON CIRCUNVALACIN ANTOFAGASTA  -------  Posada Flor del Desierto, Ruta 5 Norte, Agua Verde, Taltal, Provincia de Antofagasta, Región de Antofagasta, Chile
# ['LA', 'BATALLA', 'NUMERO', '942', 'CASA DEL FONDO', 'PASAJE PORTON', 'MADERA', 'Y', 'FIERRO', 'CONCEPCION']  ------  LA BATALLA NUMERO 942, CASA DEL FONDO DEL PASAJE PORTON DE MADERA Y FIERRO CONCEPCION  -------  La Batalla, Concepción, Provincia de Concepción, Región del Biobío, 4091007, Chile
# ['PJE ARQUITECTO', 'M', 'SYLLEROS', 'R', '954', 'V', 'ILUSION', 'LOS AROMOS', 'COLINA']  ------  PJE. ARQUITECTO M M SYLLEROS R 954 V. ILUSION LOS AROMOS COLINA  -------  Pasaje Mauricio Sylleros, Población Los Aromos, San Miguel, Colina, Provincia de Chacabuco, Región Metropolitana de Santiago, Chile
# ['AVENIDA', 'ANDALICAN', 'NRO', 'DOMICILIO', '25', 'DEPTO', 'BLOCK', '0', 'SITIO', 'MEJILLONES', 'LAA', 'TOMAS', 'CALLE', 'CHILE']  ------  AVENIDA ANDALICAN.NRO DOMICILIO 25 DEPTO BLOCK 0 SITIO 25 MEJILLONES LAA TOMAS, CALLE CHILE, MEJILLONES MEJILLONES  -------  Avenida 25, Santa Fe, Manta Central, Manta, Manabí, 130213, Ecuador
# ['CAMPAMENTO', 'GENESIS', '2', 'ENTRE', 'PORTUGAL', 'CON', 'LUIS', 'CRUZ', 'ANTOFAGSTA', 'ANTOFAGASTA']  ------  CAMPAMENTO GENESIS 2 ENTRE PORTUGAL CON  LUIS CRUZ ANTOFAGSTA ANTOFAGASTA  -------  Genesis, Población Matta, Antofagasta, Provincia de Antofagasta, Región de Antofagasta, 1240000, Chile
# sin coincidencias ['PSJ', 'VITTOR', '8341', 'TRONADOR', 'CON', 'PUNTA', 'ARENAS LA FLORIDA']  ------  PSJ VITTOR 8341 TRONADOR CON PUNTA ARENAS LA FLORIDA
# ['8', '#41', 'LOTEO', 'PATA', 'VACA', 'CERRO', 'ALTO', 'LOS ALAMOS']  ------  8 #41 LOTEO PATA PATA DE VACA CERRO ALTO LOS ALAMOS  -------  Camino a Pata de Vaca, Cerro Alto, Los Álamos, Provincia de Arauco, Región del Biobío, 4380000, Chile
# sin coincidencias ['LOS NARANJOS', '251', 'POBLACION', 'ARTURO', 'PRATT', 'MAIPO', 'BUIN']  ------  LOS NARANJOS 251, POBLACION ARTURO PRATT, MAIPO BUIN, MAIPO BUIN
# sin coincidencias ['LA', 'CAPELLANIA', 'PARCELA', '82', 'CARTAGENA']  ------  LA CAPELLANIA PARCELA 82 CARTAGENA
# sin coincidencias ['BALMACEDA', '274', 'REUMEN', 'PAILLACO']  ------  BALMACEDA 274 REUMEN REUMEN PAILLACO
# sin coincidencias ['CHACABUCO', '910', 'CONDOMINIO', 'AMANCAY', 'QUILLOTA']  ------  CHACABUCO 910 CONDOMINIO AMANCAY QUILLOTA
# sin coincidencias ['SAN MARTIN', 'CASA 109', 'CHIGUAYANTE']  ------  SAN MARTIN CASA 109 CHIGUAYANTE
# sin coincidencias ['EL TRIGAL', 'CASA', 'TEMUCO']  ------  EL TRIGAL CASA TEMUCO
# sin coincidencias ['NOGALES', '140', 'C', 'SAN BERNARDO']  ------  NOGALES 140 C SAN BERNARDO SAN BERNARDO
# sin coincidencias ['SAN MARTIN', 'MINIMARKETYBAZAR', 'PAZLO', 'PEMUCO']  ------  SAN MARTIN MINIMARKETYBAZAR PAZLO PEMUCO
# sin coincidencias ['CJON', 'PRISCO', 'CONTA', 'CASA 3', 'LA', 'SERENA']  ------  CJON. PRISCO CONTA CASA 3 LA SERENA
# ['ESTEBAN', 'YACKSIC', 'RAKELA', '154', 'PUNTA', 'ARENAS', 'MAGALLANES', 'NUMERACION', '154B', 'POR', 'AVDA', 'FREY']  ------  ESTEBAN YACKSIC RAKELA 154.PUNTA ARENAS.MAGALLANES. NUMERACION 154B POR AVDA FREY PUNTA ARENAS  -------  Esteban Jacksic Rakela, José Grimaldi, Punta Arenas, Provincia de Magallanes, Región de Magallanes y de la Antártica Chilena, 6200000, Chile
# ['L-45', 'LINARES', 'MAULE', 'IGLESIA', 'EVANGELICA', 'ENCUENTRO', 'PAZ', 'LLEPO', 'PASADO', 'PUENTE', 'TRES', 'ARCOS']  ------  L-45 SN.LINARES.MAULE. IGLESIA EVANGELICA ENCUENTRO DE PAZ LLEPO PASADO PUENTE TRES ARCOS LINARES  -------  Ruta L-45, Tres Esquinas, Linares, Provincia de Linares, Región del Maule, Chile
# ['SAN CRISTOBAL', 'CUATRO', '587', 'POR', 'AVENIDA', 'COLOMBIA', 'ENTRE', 'ENRIQUE', 'OLIVARES', 'Y', 'SANTA', 'AMALIA LA FLORIDA']  ------  SAN CRISTOBAL CUATRO 587 POR AVENIDA COLOMBIA ENTRE ENRIQUE OLIVARES Y SANTA AMALIA LA FLORIDA  -------  Avenida Cuatro Esquinas, Condominio Santa Margarita, La Serena, Provincia de Elqui, Región de Coquimbo, 1721411, Chile
# ['ARTURO', 'PRAT', 'SITIO', 'DENTRO', 'ANTENA', 'MOVIL', 'CASA', 'ROJA', 'LADRILLOS', 'REJA', 'NEGRA', 'PUCHUNCAVI']  ------  ARTURO PRAT SITIO DENTRO ANTENA MOVIL CASA ROJA DE LADRILLOS REJA NEGRA PUCHUNCAVI  -------  PB1916-Parada 1 / Arturo Prat - Manuel A. Matta, Avenida Manuel Antonio Matta, Villa San Francisco, Quilicura, Provincia de Santiago, Región Metropolitana de Santiago, 8700000, Chile
# ['CAM', 'RUPERTO', 'MANCILLA LA VARA', 'MANO', 'DERECHA', 'CASA', 'COLOR', 'CAFE', '2', 'PISOS', 'PUERTO', 'MONTT']  ------  CAM. RUPERTO MANCILLA LA VARA MANO DERECHA CASA COLOR CAFE 2 PISOS PUERTO MONTT  -------  Pasaje Ruperto Mancilla, Senda Sur, Puerto Montt, Provincia de Llanquihue, Región de Los Lagos, Chile

# %%
res
# Out:
#                                 DIRECCION DE DOMICILIO COMUNA DOMICILIO  \
# 4    MARIA VELIZ ALCAYAGA, VALLENAR, ATACAMA, CHILE...         VALLENAR
# 8         UNO 11 POSTE 669700 MINA CARACOLES RINCONADA      SAN ESTEBAN
# 11   PJE. QUILLAY 1485 POBLACION EL BOSQUE DE OCALI...            ANGOL
# 13   LOS CLAVELES 66.ERCILLA.LA ARAUCANIA. VILLA MI...          ERCILLA
# 16                            EMA QUIROGA LAGUNA VERDE       VALPARAISO
# 18   PASAJE LOMA CORTADA SN.CURARREHUE.LA ARAUCANIA...       CURARREHUE
# 21            CHACABUCO 3662 POBLACION GUSTAVO LEPAIGE           CALAMA
# 27   AURORA 9108 DEPTO 21 A, PRIMER BLOCK ROJO, FRE...         PUDAHUEL
# 34                  VICTOR JARA 11358 DPTO 201 LOTEO B       LA PINTANA
# 37   CAMPAMENTO GENESIS 2 CASA A48 LUIS CRUZ MARTIN...      ANTOFAGASTA
# 38   H DE LA CONCEPCION #1994 BLOCK 15 DESP 31 IQUIQUE          IQUIQUE
# 40                       SALAS 328 CA E POR EL ALMACEN         RECOLETA
# 41   EJERCITO LIBERTADOR 2020 CIUDAD DEL SOL ESTAPA...      PUENTE ALTO
# 45   SIN CALLE SN.RETIRO.MAULE. SANTA ISABEL SN POS...           RETIRO
# 52                                LA TORRE 2073 CENTRO           CALAMA
# 54   EL PRADO QUILLAY 444 106 CASABLANCA EL PRADO Q...       CASABLANCA
# 58   MALLIN DEL TREILE SN.LONQUIMAY.LA ARAUCANIA. K...        LONQUIMAY
# 61                          PULGAR 8950 VILLA OHIGGINS       LA FLORIDA
# 63   AVDA CIRCUNVALACION PTE SN.RANCAGUA.OHIGGINS. ...         RANCAGUA
# 66                                   MANOLETE 219 CASA         LO PRADO
# 76                   MIGUEL GRAU 1035 MIGUEL GRAU 1035      ANTOFAGASTA
# 95   PASAJE ROBERTO TAPIA CASTILLO 960 VALLENAR VIL...         VALLENAR
# 114  VIA SIN NOMBRE SN.REQUINOA.OHIGGINS. VILLA JUA...         REQUINOA
# 119  OLIVETO 1555 A LA VUELTA DE POMBAL TIENE MALA ...      CERRO NAVIA
# 121  JALISCO 3866, LO ESPEJO, CHILE ENTRE HABANA Y ...      LA CISTERNA
# 122  SIN CALLE SN.VICTORIA.LA ARAUCANIA. COMUNIDAD ...         VICTORIA
# 131  RINCONADA DE CATO SN.CHILLAN.NUBLE. CAMINO LA ...          CHILLAN
# 147  PADRE DE VALDIVIA 225 SALAMANCA CHALINGA SECTO...        SALAMANCA
# 158      MARCOS MATURANA #2741 POBLACION INDEPENDENCIA           CALAMA
# 159  PASJE.LOS JUNCOS 05 VL.CANELILLO.ILLAPEL BAJAN...          ILLAPEL
#
#                                        NUEVA DIRECCION          X          Y
# 4                                                 None        NaN        NaN
# 8    Ruta E-821, Hacienda Rinconada de Los Andes, E... -32.800571 -70.715278
# 11   Pasaje, Villa El Vaticano, Callejones, San Vic... -34.442319 -71.088176
# 13                                                None        NaN        NaN
# 16                                                None        NaN        NaN
# 18   300, Pasaje Santa Sofía, Comunidad Huichacura ... -38.777519 -72.588531
# 21                                                None        NaN        NaN
# 27   Calle Jaime Guzmán Errázuriz, Lomas del Estrec... -53.183965 -70.930572
# 34   Chile, 23 de Agosto, Loteo Apaza, Municipio de... -24.385761 -65.272172
# 37   Rua Chile, Vila Souza, Mirassol, Região Imedia... -20.814314 -49.500920
# 38   Conde de la Conquista, Camino a La Punta, La P... -34.001818 -70.646273
# 40   Recoleta, California, Tomé, Provincia de Conce... -36.622126 -72.945771
# 41   Alto del Sol, Altos del Sol, Talagante, Provin... -33.671261 -70.943905
# 45   Calle Río Maule, Población Don Sebastian, Sant... -35.483463 -71.757812
# 52                                                None        NaN        NaN
# 54   Calle de Chile, Las Américas, Parla Este, Parl...  40.226938  -3.763306
# 58   Camino Mallín Del Trailer, Comunidad Mallín de... -38.426382 -71.383929
# 61                                                None        NaN        NaN
# 63   Copec, Avenida Cachapoal, Población Municipal,... -34.189016 -70.751332
# 66   219, Manolete, Villa Ecuador, Lo Prado, Provin... -33.450731 -70.710416
# 76                                                None        NaN        NaN
# 95   Pasaje Hermano Raúl Figueroa Tapia, Villa Herm... -32.896999 -71.251637
# 114                                               None        NaN        NaN
# 119  Oliveto, Población El Montijo, Cerro Navia, Pr... -33.421232 -70.755950
# 121  Ex Edificio Central (Ministerio de Educacion y... -25.286376 -57.637698
# 122  Ruta 5 Sur, Santa Amelia, Victoria, Provincia ... -38.163415 -72.311853
# 131  Ruta N-62, Rinconada, Chillán, Provincia de Di... -36.611807 -72.302554
# 147  Escuela Diaguitas de Chalinga, 496, Pedro de V... -31.769002 -70.977673
# 158                                               None        NaN        NaN
# 159                                               None        NaN        NaN

# %%
print("A")
